# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import json, re
from tqdm import tqdm_notebook
from uuid import uuid4
 
## Torch Modules
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
 
from sklearn.utils import class_weight
 
 
## Mount Drive into Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
if torch.cuda.is_available():  
    device = torch.device("cuda")
    print('We will use the GPU:', torch.cuda.get_device_name(0))
    
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# We will use the GPU: Tesla T4

# %%
# !pip install pytorch-transformers
# Out:
# Collecting pytorch-transformers
#   Downloading https://files.pythonhosted.org/packages/a3/b7/d3d18008a67e0b968d1ab93ad444fc05699403fa662f634b2f2c318a508b/pytorch_transformers-1.2.0-py3-none-any.whl (176kB)
#      |████████████████████████████████| 184kB 18.5MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pytorch-transformers) (4.41.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from pytorch-transformers) (2019.12.20)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 40.8MB/s
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/9b/e5/96f7156e6ebf7ab992471479c3c55f0be2f31360fcdcac21aa6f782c036a/boto3-1.17.57-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 46.9MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytorch-transformers) (2.23.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 54.4MB/s
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-transformers) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-transformers) (1.19.5)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting botocore<1.21.0,>=1.20.57
#   Downloading https://files.pythonhosted.org/packages/94/52/aa266c9594e279799ded419caac56365796ce686b97762b9c8620b2ba988/botocore-1.20.57-py2.py3-none-any.whl (7.4MB)
#      |████████████████████████████████| 7.4MB 33.8MB/s
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/63/d0/693477c688348654ddc21dcdce0817653a294aa43f41771084c25e7ff9c7/s3transfer-0.4.2-py2.py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 5.4MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->pytorch-transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->pytorch-transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->pytorch-transformers) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.0->pytorch-transformers) (3.7.4.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.57->boto3->pytorch-transformers) (2.8.1)
# ERROR: botocore 1.20.57 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: sentencepiece, jmespath, botocore, s3transfer, boto3, sacremoses, pytorch-transformers
# Successfully installed boto3-1.17.57 botocore-1.20.57 jmespath-0.10.0 pytorch-transformers-1.2.0 s3transfer-0.4.2 sacremoses-0.0.45 sentencepiece-0.1.95

# %%
train = pd.read_csv("/content/train.csv", header = None, names = ["utterance", "slots", "label"])
test = pd.read_csv("/content/test.csv", header = None, names = ["utterance", "slots", "label"])
validation = pd.read_csv("/content/dev.csv", header = None, names = ["utterance", "slots", "label"])
 
#collating the data 
dataset1 = train.append(validation).reset_index(drop=True)
dataset = dataset1.append(test).reset_index(drop=True)
dataset = dataset[["utterance", "label"]]
dataset.head()
# Out:
#                                            utterance                 label
# 0  BOS Sir I created a new env with python 3.7 bu...             need_help
# 1         BOS above problem how will it solve ?? EOS             need_help
# 2                  BOS Hello sir is there anyone EOS             Greetings
# 3  BOS i think canvas login problem was due to br...                 great
# 4  BOS Please provide me with the link to python ...  community_class_link

# %%
#Removing BOS
corpus =[]
 
for i in range(len(dataset["utterance"])):
  val = dataset["utterance"][i]
  match =re.sub("[^a-zA-Z]", " ", val)
  #print(match)
  match = re.sub("BOS ", "", match)
  #print(match)
  match = re.sub(" EOS", "", match)
  #print(match)
  match = "".join(match)
  
  corpus.append(match)
 
dataset["utterance"] = pd.DataFrame(corpus)
dataset
# Out:
#                                               utterance                 label
# 0     Sir I created a new env with python     but th...             need_help
# 1                    above problem how will it solve                need_help
# 2                             Hello sir is there anyone             Greetings
# 3     i think canvas login problem was due to browse...                 great
# 4      Please provide me with the link to python class   community_class_link
# ...                                                 ...                   ...
# 4334  x tf Variable   xinit tf global variables init...             need_help
# 4335   partlist type started alt  OId ad     d    a ...                     O
# 4336                                     Thanks you sir             Thank_you
# 4337   URIObject uri https   api asm skype com v  ob...                     O
# 4338  Sir I m from   nd Feb ml batch   I have a quer...  mongodb_installation
#
# [4339 rows x 2 columns]

# %%
max_others=dataset['label'].value_counts()
max_others
# Out:
# need_help                       952
# O                               763
# Greetings                       408
# Thank_you                       353
# good_bye                        213
#                                ...
# pycharm_path_set                  1
# large_data_handle_prod_query      1
# assignment_matplotlib             1
# then_reply                        1
# rasa_nlu_details                  1
# Name: label, Length: 171, dtype: int64

# %%
dataset
# Out:
#                                               utterance                 label
# 0     Sir I created a new env with python     but th...             need_help
# 1                    above problem how will it solve                need_help
# 2                             Hello sir is there anyone             Greetings
# 3     i think canvas login problem was due to browse...                 great
# 4      Please provide me with the link to python class   community_class_link
# ...                                                 ...                   ...
# 4334  x tf Variable   xinit tf global variables init...             need_help
# 4335   partlist type started alt  OId ad     d    a ...                     O
# 4336                                     Thanks you sir             Thank_you
# 4337   URIObject uri https   api asm skype com v  ob...                     O
# 4338  Sir I m from   nd Feb ml batch   I have a quer...  mongodb_installation
#
# [4339 rows x 2 columns]

# %%
def preprocess(text):

    text=text.lower()
    # remove hyperlinks
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'http?:\/\/.*[\r\n]*', '', text)
    #Replace &amp, &lt, &gt with &,<,> respectively
    text=text.replace(r'&amp;?',r'and')
    text=text.replace(r'&lt;',r'<')
    text=text.replace(r'&gt;',r'>')
    #remove hashtag sign
    #text=re.sub(r"#","",text)   
    #remove mentions
    text = re.sub(r"(?:\@)\w+", '', text)
    #text=re.sub(r"@","",text)
    #remove non ascii chars
    text=text.encode("ascii",errors="ignore").decode()
    #remove some puncts (except . ! ?)
    text=re.sub(r'[:"#$%&\*+,-/:;<=>@\\^_`{|}~]+','',text)
    text=re.sub(r'[!]+','!',text)
    text=re.sub(r'[?]+','?',text)
    text=re.sub(r'[.]+','.',text)
    text=re.sub(r"'","",text)
    text=re.sub(r"\(","",text)
    text=re.sub(r"\)","",text)
    
    text=" ".join(text.split())
    return text

dataset['utterance'] = dataset['utterance'].apply(preprocess)

# %%
dataset
# Out:
#                                               utterance                 label
# 0     sir i created a new env with python but the li...             need_help
# 1                       above problem how will it solve             need_help
# 2                             hello sir is there anyone             Greetings
# 3     i think canvas login problem was due to browse...                 great
# 4       please provide me with the link to python class  community_class_link
# ...                                                 ...                   ...
# 4334  x tf variable xinit tf global variables initia...             need_help
# 4335  partlist type started alt oid ad d a c aaf a c...                     O
# 4336                                     thanks you sir             Thank_you
# 4337  uriobject uri https api asm skype com v object...                     O
# 4338  sir i m from nd feb ml batch i have a query re...  mongodb_installation
#
# [4339 rows x 2 columns]

# %%
plt.figure(figsize=(20,12))
dataset['label'].value_counts().plot.pie(autopct='%1.2f%%', fontsize=10, startangle=90)

# %%
#Lets Select all ticket Assignment groups which have only one ticket
rare_grps= dataset[dataset.groupby("label")["label"].transform('size') <30]['label'].unique()
rare_grps
# Out:
# array(['community_class_link', 'assignment_pandas', 'assignment_doubt',
#        'yes_reply', 'more_query', 'need_skype_call', 'stats',
#        'class_link', 'python_super_class', 'power-bi_tableau_dashboard',
#        'anaconda_navigator_open', 'deployment', 'image_scrapper',
#        'word_file_input_query', 'powerbi_query', 'resume_query',
#        'course_details', 'python_conversion_datatype', 'batch_details',
#        'pyspark', 'PlotlyRequestError', 'cuda_driver_install',
#        'youtube_video_availability', 'seaborn', 'sorry',
#        'python_requirements_install', 'Dashboard_access',
#        'dashboard_file_error', 'colab_help', 'heroku_deployment',
#        'assignment_python', 'user_email', 'community_class',
#        'mysql_installation', 'gcp_deployment', 'mongodb_installation',
#        'ignore', 'recordings_not_avilable', 'pycharm_connection',
#        'assignment_stats', 'NewBatch_details', 'powerbi_installation',
#        'dashboard_add_recording', 'assignment_data_visulization',
#        'canvas_login_problem', 'cnn_question', 'Plotly_installation',
#        'review_scrapping', 'dashboard_content_view_problem',
#        'tensorflow_installation', 'doubt_clear_session_recording',
#        'pandas_groupby', 'selennium_installation', 'laugh',
#        'postman_url_incorrect_error', 'python_arg_kwarg',
#        'system_configurations', 'pandas_cross_join',
#        'refer_class_lecture', 'dashboard_how_to_use', 'file',
#        'payment_detail', 'ml_dl_based_ans', 'assignment_pandas_link',
#        'GCP_chatbot', 'github', 'pandas_general_query',
#        'previous_recordings', 'string_python', 'Dashboard_details',
#        'course_contents', 'pycharm_interpreter_selection',
#        'assignment_link', 'jupyter_notebook', 'assignment_numpy',
#        'anaconda_jnotebook_run', 'course_timings', 'wait_reply',
#        'career_transition', 'python_astype', 'list_comprehensions',
#        'numpy_error', 'assignment_evaluation', 'Exception_builtin_errors',
#        'certificates_enquery', 'user_number',
#        'large_data_handle_prod_query', 'doubt_clear_session',
#        'pycharm_path_set', 'pivotal_deployment', 'python_import_error',
#        'chatbot_telegram_connection_issue', 'class_registeration_link',
#        'azure_luis_deployment', 'usecase_document_contains_letter',
#        'assingment_uploading_error', 'course_registration', 'EDA_code',
#        'aws_deployment_error', 'assignment_matplotlib', 'powerbi_dataset',
#        'file_not_found', 'aws_lex_smtp_error', 'anaconda_macos', 'cmd',
#        'zoom_mute_disable_reply', 'rasa_nlu_details',
#        'dashboard_activation', 'azure_luis_understanding_issue',
#        'assignment_powerbi', 'powerbi_certificate',
#        'large_data_handle_query', 'anaconda_prompt', 'CNN_code_error',
#        'assignment_exception_handling', 'logistic_regression',
#        'installation_graphviz', 'assignment_issue', 'chatbot_issue',
#        'visualization_powerbi_query', 'assignment_list_comprehension',
#        'bot_reply', 'str_method_output', 'rasa_installation',
#        'books_availablity_drive', 'azure_luis_500_error', 'postman_error',
#        'refer_syllabus', 'user_name', 'dialog_flow_email_issue',
#        'tenserflow_setup', 'then_reply', 'conda_environment',
#        'aws_lex_account_query', 'zoom_screen_share', 'bot_timing',
#        'assignment_by_github', 'anconda_installation',
#        'enter_query_indetails', 'heroku_installation',
#        'canvas_details_edit', 'mongodb_connection',
#        'choosing_no_of_epochs', 'decision_tree_ML',
#        'ineuron_challenge_details', 'svm_doubt', 'select_course_id',
#        'drive_code_colab', 'mysql', 'doubt_session_link',
#        'books_availablity_dashboard', 'github_how_to_use', 'system_issue',
#        'python_oops', 'python_abstract', 'pycharm_error',
#        'data_science_architecture_class'], dtype=object)

# %%
#Lets check the total number of rare assignment groups
rare_grps.size
# Out:
# 157

# %%
#Create a different dataframe for the tickets belongs to the rare groups
rare_df = dataset[dataset['label'].isin(rare_grps)]
rare_df.shape
# Out:
# (819, 2)

# %%
# Rename the Assignment group attribute
rare_df['label'] = 'need_help'
#Lets check whether the group name has changed to 'others'
print(rare_df['label'].head(3))
# Out:
# 4     need_help
# 10    need_help
# 11    need_help
# Name: label, dtype: object
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#creating a dataframe excluding the rare groups from our original data
grp_exl_df = dataset[~dataset['label'].isin(rare_grps)]
grp_exl_df.shape
# Out:
# (3520, 2)

# %%
#Now lets add the rare groups df (having one assignment group as 'others') to the excluded dataframe 
ticket_df = pd.concat([grp_exl_df,rare_df]).reset_index(drop=True)
ticket_df.shape
# Out:
# (4339, 2)

# %%
ticket_df
# Out:
#                                               utterance      label
# 0     sir i created a new env with python but the li...  need_help
# 1                       above problem how will it solve  need_help
# 2                             hello sir is there anyone  Greetings
# 3     i think canvas login problem was due to browse...      great
# 4                                            understood      great
# ...                                                 ...        ...
# 4334                    melody itni chocolatey kuyn hai  need_help
# 4335  hello team could you plz tell me the domains o...  need_help
# 4336  i have a doubt regarding one of the eda apos s...  need_help
# 4337  while trying to test code from postman am gett...  need_help
# 4338  sir i m from nd feb ml batch i have a query re...  need_help
#
# [4339 rows x 2 columns]

# %%
ticket_df['label'].value_counts().count()
# Out:
# 14

# %%
store=list(ticket_df.utterance.values)
store
# Out:
# ['sir i created a new env with python but the library for which i got error quot mkl random quot is not compatible with python',
#  'above problem how will it solve',
#  'hello sir is there anyone',
#  'i think canvas login problem was due to browser i tried in chrome and it worked',
#  'understood',
#  'tq',
#  'so ill just copy paste what i wanted to know',
#  'sir any sujjestion to overcome this error',
#  'np random choice apos goal area apos apos goal line apos p',
#  'uriobject uri https api asm skype com v objects sa d b f eebb e c d b d url thumbnail https api asm skype com v objects sa d b f eebb e c d b d views imgt anim type picture doc id sa d b f eebb e c d b d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b f eebb e c d b d https login skype com login sso go xmmfallback pic sa d b f eebb e c d b d a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'i applied for python in depth and power bi course i am yet to get access to dashboard could you please take care',
#  'ok can you check and tell me my registered id is a href mailto paragjp gmail com paragjp gmail com a and register mobile no is',
#  'mediaalbum albumid edcfcd f f ae f b dc a mediaalbum',
#  'uriobject uri https api asm skype com v objects sa d f f ed d b a b url thumbnail https api asm skype com v objects sa d f f ed d b a b views imgt anim type picture doc id sa d f f ed d b a b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f f ed d b a b https login skype com login sso go xmmfallback pic sa d f f ed d b a b a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'how to open terminal from the project folder to execute the git command',
#  'actually i am pursuing my msc in data analytics i was having bootcamp during the weekend hence i couldn apos t attend the classes on th and th oct now i apos m going through the recordings i feel so confident after attending the trainings from ineuron thank you so much',
#  'thank you',
#  'because sentimental analysis is highly co related to brand awreness and hence i want to multiply it with every variable so plz guide me or enlighten me if am doing wrong',
#  'hi',
#  'it will not show anything for download',
#  'in same way i tried to execute another one and getting this issue',
#  'i am shiva from course ml ndfeb batch',
#  'hi',
#  'thank you so much',
#  'okay thank you ss type smile ss',
#  'sir my internship meeting is tomorrow and those who ll not attend will not go further but i requested many times through mail and this medium that i have a family function in rural area so i may not be able to attend the session so i asked to pls suggest me whether i should cancel the trip or not but no response was given and now i m in a rural area and i need atleast days to move from here as transport problem is there so what should i do will i lose my internship chance',
#  'oh thank you not jus one i hope all of my assignments will be viewd n evaluated successfully',
#  'hello sir is there anyone',
#  'please enroll me for the next internship i would be great favor',
#  'still getting the same error',
#  'hi',
#  'done sir connected',
#  'hello sir i would like to know when will next batch of intern will start',
#  'sir i think my file is also ok just the point is url is showing incorrect',
#  'how to install all package in pycharm',
#  'i received an email from ineuron about an internship can you explain about the internship i have not completed the course and what is the skill of doing an internship and how many months it will be taken to complete the internship',
#  'okay',
#  'partlist type started alt callid c b d da afd f a b f part identity live cid b eb e name saritha jaligama name part part identity live cid a bf name support ineuron ai name part partlist',
#  'ok sir',
#  'thanks',
#  'uriobject uri https api asm skype com v objects sa d e ee a d d c f fc d d url thumbnail https api asm skype com v objects sa d e ee a d d c f fc d d views imgt anim type picture doc id sa d e ee a d d c f fc d d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e ee a d d c f fc d d https login skype com login sso go xmmfallback pic sa d e ee a d d c f fc d d a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'if i wrote a flask program where can i see the output e m a live cid b eb e ts ms ts t e m',
#  'uriobject uri https api asm skype com v objects sa d d b dbc cfb b dd a f url thumbnail https api asm skype com v objects sa d d b dbc cfb b dd a f views imgt anim type picture doc id sa d d b dbc cfb b dd a f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d b dbc cfb b dd a f https login skype com login sso go xmmfallback pic sa d d b dbc cfb b dd a f a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'ok',
#  'thank you sir',
#  'hello sir',
#  'yes same env is there',
#  'ok sir',
#  'thnx',
#  'but i was just curious what was the use of that code here',
#  'uriobject uri https api asm skype com v objects cus d dca ee f d f de e url thumbnail https api asm skype com v objects cus d dca ee f d f de e views imgt anim type picture doc id cus d dca ee f d f de e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic cus d dca ee f d f de e https login skype com login sso go xmmfallback pic cus d dca ee f d f de e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'since the beginning of the class',
#  'already done',
#  'have did that also',
#  'ok please let me check',
#  'i have send it again could you please check it',
#  'please check',
#  'got it',
#  'how to fix it',
#  'hii sir',
#  'could you please have a look at it',
#  'i need some advice and guidance from you my apologies for bothering you with these frivolous questions',
#  'but i am getting a error so could you please help me to resolve this error',
#  'uriobject uri https api asm skype com v objects sa d f bedb e c d c fd fef url thumbnail https api asm skype com v objects sa d f bedb e c d c fd fef views imgt anim type picture doc id sa d f bedb e c d c fd fef width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f bedb e c d c fd fef https login skype com login sso go xmmfallback pic sa d f bedb e c d c fd fef a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'yes i got dashboard',
#  'ohh sorry',
#  'it is showing invalid syntex error',
#  'okay thank you',
#  'hi',
#  'sorry is this sudhanshu sir',
#  'file quot lt ipython input ce bc gt quot line print scipy stats ttest ind rvs rvs syntaxerror invalid syntax',
#  'i have taken a dataset on google review from the uci i am going to do on this sir',
#  'what is auto scaling i don apos t know',
#  'uriobject uri https api asm skype com v objects sa d a ab bee a e e ee d url thumbnail https api asm skype com v objects sa d a ab bee a e e ee d views imgt anim type picture doc id sa d a ab bee a e e ee d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a ab bee a e e ee d https login skype com login sso go xmmfallback pic sa d a ab bee a e e ee d a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'sirr what to do for mkl random',
#  'please fix this issue asap',
#  'good morning',
#  'sir was ping to chat box',
#  'uriobject uri https api asm skype com v objects sa d ae bc c b e e ba f url thumbnail https api asm skype com v objects sa d ae bc c b e e ba f views imgt anim type picture doc id sa d ae bc c b e e ba f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ae bc c b e e ba f https login skype com login sso go xmmfallback pic sa d ae bc c b e e ba f a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d ff b f e ab e f url thumbnail https api asm skype com v objects sa d ff b f e ab e f views imgt anim type picture doc id sa d ff b f e ab e f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ff b f e ab e f https login skype com login sso go xmmfallback pic sa d ff b f e ab e f a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'is machine learning a pre requisite',
#  'hi',
#  'hi',
#  'i want to replace non values in not rated',
#  'hi',
#  'uriobject uri https api asm skype com v objects sa d fe aeab ef c b fe f c url thumbnail https api asm skype com v objects sa d fe aeab ef c b fe f c views imgt anim type picture doc id sa d fe aeab ef c b fe f c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d fe aeab ef c b fe f c https login skype com login sso go xmmfallback pic sa d fe aeab ef c b fe f c a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d d c c c d d ef c bfbd url thumbnail https api asm skype com v objects sa d d c c c d d ef c bfbd views imgt anim type picture doc id sa d d c c c d d ef c bfbd width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d c c c d d ef c bfbd https login skype com login sso go xmmfallback pic sa d d c c c d d ef c bfbd a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'thank you so much',
#  'ok',
#  'mediaalbum albumid f ac d ea dbfdcb mediaalbum',
#  'i will restart the system and reinstall again',
#  'got timeout seconds error',
#  'uriobject uri https api asm skype com v objects sa d c a cb ad f f bbb url thumbnail https api asm skype com v objects sa d c a cb ad f f bbb views imgt anim type picture doc id sa d c a cb ad f f bbb width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c a cb ad f f bbb https login skype com login sso go xmmfallback pic sa d c a cb ad f f bbb a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'hi',
#  'bad gateway',
#  'no problem',
#  'but would u happen to knw when can i get in touch with sudhanshu sir through this mode of comm',
#  'so they are asking professional email id',
#  'can you please tell me how to opt out from this internship',
#  'hi',
#  'sir i used this password',
#  'sir by using forward fill how i increase the value by',
#  'how does it solve',
#  'sorry i understood output matrix and tried that i need second question explanation',
#  'uriobject uri https api asm skype com v objects sa d ca f c abcf f ca ba c url thumbnail https api asm skype com v objects sa d ca f c abcf f ca ba c views imgt anim type picture doc id sa d ca f c abcf f ca ba c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ca f c abcf f ca ba c https login skype com login sso go xmmfallback pic sa d ca f c abcf f ca ba c a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'applying remove blank rows i am still getting null values what could be issue here',
#  'how will it solve',
#  'if you didn apos t understand my problem let me know i send pics',
#  'one doubt from last class power bi it was well explained about to delete the rows having null blank value but how will we be able to delete the rows having values as missing na naan etc we know that these values are not necessary but how to handle these rows in power bi',
#  'its not working properly',
#  'hello good afternoon i apos m avinash student of june ml batch i have applied for internship that is going to start from november',
#  'hii i am vishnu derkar and i have the form for internship on aug but couldn t find my name in the list',
#  'ya i watched more video then got clarified thank you so much',
#  'partlist type ended alt callid bda ecb a e b c b c cfb part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'mediaalbum albumid a f fa e a a mediaalbum',
#  'ok sir',
#  'so what should i do',
#  'ok',
#  'no not a dashboard data set',
#  'hi',
#  'q write a python program with class concepts to find the area of the triangle using the below formula area s s a s b s c function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass class triangle def takeinput a int input quot enter the first side quot b int input quot enter the second side quot c int input quot enter the third side quot return a b c class areatriangle triangle def areatriangle a b c s a b c area s s a s b s c print quot the area of triangle is quot area obj areatriangleres obj takeinput obj areatriangle res res res',
#  'hi',
#  'hello sir is there any one',
#  'thanks',
#  'plz put your input on the file i created',
#  'can you please give me some references from where i can learn about these techniques',
#  'uriobject uri https api asm skype com v objects sa d a efdca df da d f dc f b url thumbnail https api asm skype com v objects sa d a efdca df da d f dc f b views imgt anim type picture doc id sa d a efdca df da d f dc f b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a efdca df da d f dc f b https login skype com login sso go xmmfallback pic sa d a efdca df da d f dc f b a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'let me know the solution',
#  'it worked',
#  'hi',
#  'uriobject uri https api asm skype com v objects sa d c a ea a f bf dfc url thumbnail https api asm skype com v objects sa d c a ea a f bf dfc views imgt anim type picture doc id sa d c a ea a f bf dfc width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c a ea a f bf dfc https login skype com login sso go xmmfallback pic sa d c a ea a f bf dfc a originalname v temp png originalname filesize v filesize meta type photo originalname temp png meta uriobject',
#  'still the same result in both the cases',
#  'sir please check it and tell me whether i can send the nda now if yes then to which mail id',
#  'can i get the python in my dashboard please',
#  'good afternoon sir',
#  'partlist type missed alt oid f fcc b e a f cde cfb part identity live cid b c cf name mukunthan ragavan name part part identity live cid a bf name support ineuron ai name part partlist',
#  'hi',
#  'yes',
#  'great thanks boss',
#  'good work sir',
#  'it is present just checked',
#  'what will happen if we include that column here and what will happen if we don apos t include that',
#  'sir i got the answer it is ok i got it how to solve',
#  'uriobject uri https api asm skype com v objects sa d dbbc fde f e c e b df ebaf url thumbnail https api asm skype com v objects sa d dbbc fde f e c e b df ebaf views imgt anim type picture doc id sa d dbbc fde f e c e b df ebaf width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d dbbc fde f e c e b df ebaf https login skype com login sso go xmmfallback pic sa d dbbc fde f e c e b df ebaf a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'k',
#  'thanks a lot',
#  'but when i write the command mentioned in the screenshot the command greys out',
#  'but there is some filter getting applied',
#  'sure thank u',
#  'hi sir good morning',
#  'hello this is shashidhar',
#  'it is solve its working fine',
#  'thanks',
#  'okay',
#  'i have registered already ok any ways i will wait for the dash board access',
#  'a href https drive google com file d u x nz vqw aypsukbmhfwenitqsgbo view https drive google com file d u x nz vqw aypsukbmhfwenitqsgbo view a',
#  'yup',
#  'to which one',
#  'okay',
#  'uriobject uri https api asm skype com v objects sa d f ab f bd f fc a url thumbnail https api asm skype com v objects sa d f ab f bd f fc a views imgt anim type picture doc id sa d f ab f bd f fc a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f ab f bd f fc a https login skype com login sso go xmmfallback pic sa d f ab f bd f fc a a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'hi',
#  'sure give me a second',
#  'when will the enroll machine learning and deep learning with deployment end',
#  'yes sir',
#  'i can apos t ask doubts there',
#  'sir i have imported it successfully but it is still showing this',
#  'thanks',
#  'datetime not able to change datatype',
#  'so withour anaconda i need to install every thing on my own anaconda is a distribution of all libraries used in data science',
#  'hi',
#  'sir i was just revising again with ur previous video recordings',
#  'hi',
#  'data is titanic',
#  'uriobject uri https api asm skype com v objects sa d a d d db a b a d d url thumbnail https api asm skype com v objects sa d a d d db a b a d d views imgt anim type picture doc id sa d a d d db a b a d d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a d d db a b a d d https login skype com login sso go xmmfallback pic sa d a d d db a b a d d a originalname v final dashbaord image png originalname filesize v filesize meta type photo originalname final dashbaord image png meta uriobject',
#  'okay thankyou',
#  'i was facing this issue in zoom video call yesterday',
#  'i apos m not getting what is wrong with below syntax',
#  'def gen ss type no n ss for i in range n for j in range i print quot quot end quot quot print quot r quot for p in range n n for k in range p print quot quot end quot quot print quot quot end quot quot',
#  'hello sir is there anyone',
#  'see the error please sujest onit',
#  'iplot is not working',
#  'previous chatt just check that one',
#  'class all sentences passtry subjects quot americans quot quot indians quot verbs quot play quot quot watch quot objects quot baseball quot quot cricket quot sentences sub quot quot ver quot quot obj for sub in subjects for ver in verbs for obj in objects except print apos the required statement can not be performed apos print all sentences',
#  'i check the connection',
#  'uriobject uri https api asm skype com v objects sa d f dfdf e e bf c e url thumbnail https api asm skype com v objects sa d f dfdf e e bf c e views imgt anim type picture doc id sa d f dfdf e e bf c e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f dfdf e e bf c e https login skype com login sso go xmmfallback pic sa d f dfdf e e bf c e a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'seen the above thread its the same procedure i followed',
#  'yes sure sir',
#  'uriobject uri https api asm skype com v objects sa d bf c bddcb aac a a b url thumbnail https api asm skype com v objects sa d bf c bddcb aac a a b views imgt anim type picture doc id sa d bf c bddcb aac a a b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d bf c bddcb aac a a b https login skype com login sso go xmmfallback pic sa d bf c bddcb aac a a b a originalname v picturemessage xdu r q iox png originalname filesize v filesize meta type photo originalname picturemessage xdu r q iox png meta uriobject',
#  'hithis is related to the weeks python trainingi can see that assignment for pandas is available in the module but in the grades section there is no option to submit the pandas assignment',
#  'sir i didnt get it can u tell once again what to do',
#  'uriobject uri https api asm skype com v objects sa d d d bf da c afecb f url thumbnail https api asm skype com v objects sa d d d bf da c afecb f views imgt anim type picture doc id sa d d d bf da c afecb f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d d bf da c afecb f https login skype com login sso go xmmfallback pic sa d d d bf da c afecb f a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'plz help me how can i implement it as single list',
#  'okay will try this and will revert back',
#  'hi',
#  'i also need in laptop',
#  'uriobject uri https api asm skype com v objects sa d c bdeb aebd a c url thumbnail https api asm skype com v objects sa d c bdeb aebd a c views imgt anim type picture doc id sa d c bdeb aebd a c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c bdeb aebd a c https login skype com login sso go xmmfallback pic sa d c bdeb aebd a c a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'i have a dount in one of the datasets',
#  'uriobject type audio message url thumbnail https api asm skype com v objects ea d aedd baa e da f ecee ab views thumbnail uri https api asm skype com v objects ea d aedd baa e da f ecee ab title voicemail title a href https login skype com login sso go webclient xmm amp am ea d aedd baa e da f ecee ab play a originalname v voicemail wav uriobject',
#  'are you there',
#  'thank you',
#  'bro you are not responding my problem since last days',
#  'this is compass interface',
#  'yes i am',
#  'thanks i am able to acess that',
#  'still same error',
#  'ok',
#  'ok',
#  'hello sir is there anyone',
#  'thank you',
#  'uriobject uri https api asm skype com v objects sa d e f a d adb d bd c url thumbnail https api asm skype com v objects sa d e f a d adb d bd c views imgt anim type picture doc id sa d e f a d adb d bd c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e f a d adb d bd c https login skype com login sso go xmmfallback pic sa d e f a d adb d bd c a originalname v picturemessage o rpuu o txt png originalname filesize v filesize meta type photo originalname picturemessage o rpuu o txt png meta uriobject',
#  'sir i have forgot my canvas password when i clicked forget password it should send me the password but i didn apos t get any mail what should i do',
#  'pls chk this',
#  'as in is it an extension to any of the courses or is it standalone and can be pursued by someone who wants to learn computer vision thank u',
#  'i restarted notebook but sasme error coming',
#  'sir ans is but mine was using this one',
#  'this error is coming',
#  'uriobject uri https api asm skype com v objects sa d ed be ac c d fc d ad url thumbnail https api asm skype com v objects sa d ed be ac c d fc d ad views imgt anim type picture doc id sa d ed be ac c d fc d ad width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ed be ac c d fc d ad https login skype com login sso go xmmfallback pic sa d ed be ac c d fc d ad a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d b d cf fa bb b d e url thumbnail https api asm skype com v objects sa d b d cf fa bb b d e views imgt anim type picture doc id sa d b d cf fa bb b d e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b d cf fa bb b d e https login skype com login sso go xmmfallback pic sa d b d cf fa bb b d e a originalname v picturemessage dgcm ujf e png originalname filesize v filesize meta type photo originalname picturemessage dgcm ujf e png meta uriobject',
#  'i have received mail from sudhanshu to download the course pdf',
#  'i checked multiple time impute function every time it fails when the column name police report available runs into the loop',
#  'partlist type ended alt callid e e bc f c c part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'sir how much calculus is needed in the field of the data science',
#  'but now not able to access it using the same email',
#  'i registered for the dashboard on last tuesday but still i didnt get it so plz provide it',
#  'its already done but failed',
#  'sir can u see that ok option',
#  'hello sir is there anyone',
#  'google colab is online platform so i have given code on there for execution and share link on submit assignment',
#  'uriobject uri https api asm skype com v objects sa d ad e d e bf a url thumbnail https api asm skype com v objects sa d ad e d e bf a views imgt anim type picture doc id sa d ad e d e bf a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ad e d e bf a https login skype com login sso go xmmfallback pic sa d ad e d e bf a a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'i tried but it apos s the same error',
#  'thank you so much',
#  'hello i have subscribed to both pyton and power bi courses but only received access to power bi bit could you give me access to python course as well my email is jose quintini gmail com thanks in advance',
#  'hello sir is there anyone',
#  'partlist type missed alt callid da e a db fa de b f c ea part identity live f de c ca name anshul singh name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'ok',
#  'also if one can become a full stack engineer front and back end on the products developed',
#  'hello sir i have joined the powerbi and tableau course i would like to join your python course as well if possible name kaustavid a href mailto kaustavritwik gmail com kaustavritwik gmail com a looking forward to hearing from you regards',
#  'yes',
#  'ok',
#  'sir u there',
#  'uriobject uri https api asm skype com v objects sa d cc af e d url thumbnail https api asm skype com v objects sa d cc af e d views imgt anim type picture doc id sa d cc af e d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d cc af e d https login skype com login sso go xmmfallback pic sa d cc af e d a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'hi',
#  'uriobject uri https api asm skype com v objects sa d eac dcabd d e f b url thumbnail https api asm skype com v objects sa d eac dcabd d e f b views imgt anim type picture doc id sa d eac dcabd d e f b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d eac dcabd d e f b https login skype com login sso go xmmfallback pic sa d eac dcabd d e f b a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'how to check that sir',
#  'i wanted to ask u something',
#  'sir i understood that',
#  'what you were trying to say sir',
#  'sure sir thank you',
#  'thank you',
#  'hi sir',
#  'ok',
#  'ok',
#  'i will select in those library',
#  'on the first day i had clicked launch meeting in the website and it showed the video call',
#  'how can i avail that',
#  'done sir',
#  'it shows invalid syntax',
#  'bro tell me how will it download',
#  'uriobject uri https api asm skype com v objects sa d db f e fdfbeac d ce url thumbnail https api asm skype com v objects sa d db f e fdfbeac d ce views imgt anim type picture doc id sa d db f e fdfbeac d ce width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d db f e fdfbeac d ce https login skype com login sso go xmmfallback pic sa d db f e fdfbeac d ce a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d a cf bec c bb b d b bd a url thumbnail https api asm skype com v objects sa d a cf bec c bb b d b bd a views imgt anim type picture doc id sa d a cf bec c bb b d b bd a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a cf bec c bb b d b bd a https login skype com login sso go xmmfallback pic sa d a cf bec c bb b d b bd a a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d da f c d a be d e url thumbnail https api asm skype com v objects sa d da f c d a be d e views imgt anim type picture doc id sa d da f c d a be d e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d da f c d a be d e https login skype com login sso go xmmfallback pic sa d da f c d a be d e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'ok',
#  'and submit that snap and this word fill to that mail only',
#  'instead of getting directly i apos m getting step by step procedure e m a kiran menon ts ms ts t e m',
#  'uriobject type picture uri https api asm skype com v objects sa d c d fe ffef e url thumbnail https api asm skype com v objects sa d c d fe ffef e views imgt to view this shared photo go to a href https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e a originalname v screenshot jpg filesize v meta type photo originalname screenshot jpg uriobject',
#  'i will have a look again and try for it',
#  'ss type hi wave ss',
#  'sir this is the dataset',
#  'uriobject uri https api asm skype com v objects sa d a e f a f e c a e b url thumbnail https api asm skype com v objects sa d a e f a f e c a e b views imgt anim type picture doc id sa d a e f a f e c a e b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a e f a f e c a e b https login skype com login sso go xmmfallback pic sa d a e f a f e c a e b a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'java not found and java home environment variable is not set install java and set java home to point to the java installation directory',
#  'ok will do that',
#  'uriobject uri https api asm skype com v objects sa d d bf bf d d abfb a d eab url thumbnail https api asm skype com v objects sa d d bf bf d d abfb a d eab views imgt anim type picture doc id sa d d bf bf d d abfb a d eab width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d bf bf d d abfb a d eab https login skype com login sso go xmmfallback pic sa d d bf bf d d abfb a d eab a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'thank you so much ss type smile ss',
#  'see the environment is same but the chromedriver is showing different',
#  'thanks for your help the issue has now been resolved',
#  'uriobject uri https api asm skype com v objects sa d be bb d cd fd df e c e url thumbnail https api asm skype com v objects sa d be bb d cd fd df e c e views imgt anim type picture doc id sa d be bb d cd fd df e c e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d be bb d cd fd df e c e https login skype com login sso go xmmfallback pic sa d be bb d cd fd df e c e a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'ok',
#  'so can you tell exact video or any link gt gt',
#  'uriobject uri https api asm skype com v objects sa d a bd f e a aec b bb b url thumbnail https api asm skype com v objects sa d a bd f e a aec b bb b views imgt anim type picture doc id sa d a bd f e a aec b bb b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a bd f e a aec b bb b https login skype com login sso go xmmfallback pic sa d a bd f e a aec b bb b a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'but sometime i am not able to understand code what should i do whatever you given as a support',
#  'ok sir',
#  'that apos s why i apos m requesting you sir',
#  'gr tks',
#  'i am sorry for posting silly issues i was engrossed in the code that i couldn apos t locate for the mistake',
#  'already registered but my dash board didn t get updated',
#  'the latest internship of august which i m supposed to join but failed to join the meeting that day',
#  'sir how can we remove this error',
#  'how to raise a ticket',
#  'kindly accept my invitation',
#  'sir so what is the final call is it ok if i don apos t attend tomorrow meeting will get a chance after our course completion',
#  'one more point is i am a mech engineer student and passed out in from then i was preparing for ies so i don apos t have any experience yet and a gap of years so will i be able to get the job inspite of the gap',
#  'thank you',
#  'yes',
#  'uriobject uri https api asm skype com v objects sa d cdd fa e d e e e url thumbnail https api asm skype com v objects sa d cdd fa e d e e e views imgt anim type picture doc id sa d cdd fa e d e e e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d cdd fa e d e e e https login skype com login sso go xmmfallback pic sa d cdd fa e d e e e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d c e d e e e d url thumbnail https api asm skype com v objects sa d c e d e e e d views imgt anim type picture doc id sa d c e d e e e d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c e d e e e d https login skype com login sso go xmmfallback pic sa d c e d e e e d a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'for instance if i need to find the stability of an ship after stacking the containers in it may i know what kind of model will be gud to find the stability of the ship plz suggest me an eqn of it too plzzz',
#  'i installed flask in anaconda prompt and then i imported flask in jpyter and i wrote simple hello world program now i want to see the location by cmd but im not getting the location',
#  'its working properly',
#  'i was trying to create a greeting card with python coding with the help of a youtube video i did everything same but still getting an error',
#  'hi',
#  'uriobject uri https api asm skype com v objects sa d c ae f c d b f url thumbnail https api asm skype com v objects sa d c ae f c d b f views imgt anim type picture doc id sa d c ae f c d b f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c ae f c d b f https login skype com login sso go xmmfallback pic sa d c ae f c d b f a originalname v step size doubt jpg originalname filesize v filesize meta type photo originalname step size doubt jpg meta uriobject',
#  'is the code right',
#  'ohk sir thank you',
#  'no am asking as a service i just want to know is there someone that yu can connect with mee',
#  'yes i have published it',
#  'okay',
#  'okay',
#  'can u help me on this',
#  'yes sir',
#  'can we use class operation as i have shown',
#  'the columns which i want to select is latitude and longitude so i can do that bcs i want the row which had highest latitude along with latitude and longitude i made a groupby on country country has multiple occurrences in the dataset',
#  'mediaalbum albumid a a d d a f d mediaalbum',
#  'uriobject uri https api asm skype com v objects sa d c aaa f f c cbf url thumbnail https api asm skype com v objects sa d c aaa f f c cbf views imgt anim type picture doc id sa d c aaa f f c cbf width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c aaa f f c cbf https login skype com login sso go xmmfallback pic sa d c aaa f f c cbf a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'but how much time it would it take to get a job as a data scientist as i graduated from bba',
#  'failed',
#  'but how to train the model about my application which we are testingwhat will be the data for my model to train',
#  'ok sir actually i have submitted my first assignment from assignment section',
#  'cheers',
#  'yaa sure',
#  'partlist type missed alt oid c ee d d a de f e part identity live charkhe aniket name aniket charkhe name part part identity live cid a bf name support ineuron ai name part partlist',
#  'hi',
#  'got it sir',
#  'ok',
#  'thats fanstastic sir thank u for making it easy for me i will pay it before the start of the second week of the lecture',
#  'i followed two times but in video its working properly here it getting error',
#  'thank you',
#  'sir i change the setting of the browser then i opened it again',
#  'uriobject uri https api asm skype com v objects sa d c dde ad e db fa url thumbnail https api asm skype com v objects sa d c dde ad e db fa views imgt anim type picture doc id sa d c dde ad e db fa width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c dde ad e db fa https login skype com login sso go xmmfallback pic sa d c dde ad e db fa a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'uriobject type picture uri https api asm skype com v objects sa d c d fe ffef e url thumbnail https api asm skype com v objects sa d c d fe ffef e views imgt to view this shared photo go to a href https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e a originalname v screenshot jpg filesize v meta type photo originalname screenshot jpg uriobject',
#  'sir this is rd question i am asking nd one',
#  'uriobject uri https api asm skype com v objects sa d d f a b b a aca url thumbnail https api asm skype com v objects sa d d f a b b a aca views imgt anim type picture doc id sa d d f a b b a aca width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d f a b b a aca https login skype com login sso go xmmfallback pic sa d d f a b b a aca a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'sir i would like to know how the tableau and power bi helps the mba fellow in his career',
#  'tried the same in colab also',
#  'uriobject type file uri https api asm skype com v objects sa d f a e accbfafb a a d url thumbnail https api asm skype com v objects sa d f a e accbfafb a a d views thumbnail title title ndadoc docx title description description ndadoc docx description a href https login skype com login sso go xmmfallback amp docid sa d f a e accbfafb a a d https login skype com login sso go xmmfallback amp docid sa d f a e accbfafb a a d a originalname v ndadoc docx filesize v uriobject',
#  'ok but its been more than days and yet not able to solve',
#  'uriobject uri https api asm skype com v objects sa d b bbfb bf ba f fe e url thumbnail https api asm skype com v objects sa d b bbfb bf ba f fe e views imgt anim type picture doc id sa d b bbfb bf ba f fe e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b bbfb bf ba f fe e https login skype com login sso go xmmfallback pic sa d b bbfb bf ba f fe e a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'yes sir',
#  'no sir i want to know the names of batsman with sixes they have hitted till yet',
#  'i am from ml batch can you tell me from when new internship will begin so that i can enroll for it',
#  'thank you',
#  'uriobject uri https api asm skype com v objects sa d b a f d a d d f d f url thumbnail https api asm skype com v objects sa d b a f d a d d f d f views imgt anim type picture doc id sa d b a f d a d d f d f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b a f d a d d f d f https login skype com login sso go xmmfallback pic sa d b a f d a d d f d f a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'i created new username and password',
#  'yes',
#  'am sending',
#  'ss type hi wave ss',
#  'find a list within a list and then reverse all the strings within that list then in the reversed list reverse all the characters of the string in that list',
#  'hi',
#  'ok thank you',
#  'we have to save assignment in public or private',
#  'sir i am not able to understand the problem statement sir by looking at context and content sir',
#  'also can u share the ppt slide he mentioned',
#  'i received the mail regarding the internship letter',
#  'create the below pattern using nested for loop in python',
#  'i have a dount in one of the datasets',
#  'i have enrolled for python as well yesterday but couldn t see them in dashboard hope its in progress',
#  'nd wt is the exact status of that batch like wt s learning point they are at',
#  'please see it once',
#  'hello sir can you suggest which domain i should choose for internship i am student year exp wants to get job quickly and good package which domain would you suggest',
#  'thank you',
#  'okay will try this now',
#  'uriobject uri https api asm skype com v objects sa d e b cee e cf b url thumbnail https api asm skype com v objects sa d e b cee e cf b views original type file doc id sa d e b cee e cf b to view this file go to a href https login skype com login sso go webclient xmm amp docid sa d e b cee e cf b https login skype com login sso go webclient xmm amp docid sa d e b cee e cf b a originalname v untitled png originalname filesize v filesize uriobject',
#  'uriobject uri https api asm skype com v objects sa d b b b e b e bbda url thumbnail https api asm skype com v objects sa d b b b e b e bbda views imgt anim type picture doc id sa d b b b e b e bbda width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b b b e b e bbda https login skype com login sso go xmmfallback pic sa d b b b e b e bbda a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'i am new to the zoom call',
#  'and also i have registered before days and again i have registered today as well',
#  'ss type smile ss',
#  'this code here',
#  'ok thanks',
#  'because if it is for statistics we haven apos t started it yet',
#  'uriobject uri https api asm skype com v objects ea d fbb fb bfbdbfe a cefde url thumbnail https api asm skype com v objects ea d fbb fb bfbdbfe a cefde views original type file doc id ea d fbb fb bfbdbfe a cefde to view this file go to a href https login skype com login sso go webclient xmm amp docid ea d fbb fb bfbdbfe a cefde https login skype com login sso go webclient xmm amp docid ea d fbb fb bfbdbfe a cefde a originalname v bai docx originalname filesize v filesize uriobject',
#  'hihow shall i submit my assignment on the dashboard i have completed my assignment which was given yesterday but i apos m not able to figure out how to submit it could you please help me with this',
#  'ok thanks sir',
#  'mediaalbum albumid ad c ea ad fcf efead a mediaalbum',
#  'sir this project is reviewscrapper i was watching recorded video also and just finished it',
#  'fine',
#  'still getting the authentication error',
#  'where is blog link',
#  'yes',
#  'partlist type started alt oid f ec df e b d d part identity live cid fe b b c f name vikash singh name part part identity live cid a bf name support ineueon ai name part partlist',
#  'hi there',
#  'ss type hi wave ss',
#  'uriobject uri https api asm skype com v objects sa d bd d e b fb be a url thumbnail https api asm skype com v objects sa d bd d e b fb be a views imgt anim type picture doc id sa d bd d e b fb be a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d bd d e b fb be a https login skype com login sso go xmmfallback pic sa d bd d e b fb be a a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'partlist type missed alt callid d aa c d a b b a d a part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'i have this one',
#  'it worked',
#  'how can i do that sir any suggestions',
#  'no i need an internship and i don apos t have that much time to wait till jan and i have basic knowledge in machine learning and deep learning for clear understanding i joined ineuron',
#  'hi',
#  'sir after passing pip install r requirements txt',
#  'hello',
#  'uriobject uri https api asm skype com v objects sa d ea a bee e b f a fb cc url thumbnail https api asm skype com v objects sa d ea a bee e b f a fb cc views imgt anim type picture doc id sa d ea a bee e b f a fb cc width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ea a bee e b f a fb cc https login skype com login sso go xmmfallback pic sa d ea a bee e b f a fb cc a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'okay thanks',
#  'hi',
#  'and my output on python is apos ruu apos',
#  'any web invite will be send to mail or in canvas how to join',
#  'but the url which i entered is correct right',
#  'hi',
#  'partlist type ended alt callid bbc a ee b f f a d part identity live cibim name cibi m name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'for python will it show in ineuron channel',
#  'in today apos s class i got to know that we shall submit our assignments via google colab i have already submitted few assignments related to mldl th june batch via github url will it be okay',
#  'still not opening sir',
#  'u there',
#  'ok sir i am reinstalling evry thing now',
#  'yes sir',
#  'k sir will get back to you',
#  'i have applied for a job',
#  'i am in my bca final year sir currently',
#  'i will check if i can connect with the registered email which is with canvas',
#  'partlist type missed alt callid c e e a a d db f c part identity live cid f name sarthak awasthi name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'days np linspace num plt figure figsize plt plot months max temp apos ro apos plt plot days yearly temps days res max apos r apos plt plot months min temp apos bo apos plt plot days yearly temps days res min apos b apos plt xlabel apos month apos plt ylabel apos temperature circ c apos plt show',
#  'is it for the next new batch members',
#  'i tried to google some solution and tried few options but didn apos t work',
#  'ok',
#  'ok sir',
#  'ok',
#  'i dont have dashboard access please give access',
#  'thank u sir its working now',
# ...
#  'uriobject uri https api asm skype com v objects sa d f c fb e c b f e e e url thumbnail https api asm skype com v objects sa d f c fb e c b f e e e views imgt anim type picture doc id sa d f c fb e c b f e e e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f c fb e c b f e e e https login skype com login sso go xmmfallback pic sa d f c fb e c b f e e e a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'i am waiting np',
#  'leave it',
#  'uriobject uri https api asm skype com v objects sa d c a d f b dd d e d ae url thumbnail https api asm skype com v objects sa d c a d f b dd d e d ae views imgt anim type picture doc id sa d c a d f b dd d e d ae width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c a d f b dd d e d ae https login skype com login sso go xmmfallback pic sa d c a d f b dd d e d ae a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'can i have the link please',
#  'code that i have written',
#  'bro understand but file is not running now',
#  'to make it simple to understand for an input keyword i need to collect extract certain features like views clicks impressions ctr etc',
#  'file name exactly i dont know just u check file name sometimes file run or some time getting error',
#  'yes sure sir i will',
#  'bro',
#  'okay',
#  'hi sir can i submit the assignments by this week end',
#  'hi',
#  'is this an internship meeting',
#  'i have register to the python for data science yesterday but still not it on the canvas dashboard a href mailto hiranf yahoo com hiranf yahoo com a',
#  'uriobject uri https api asm skype com v objects sa d a dabd a cb c fae fa cfb url thumbnail https api asm skype com v objects sa d a dabd a cb c fae fa cfb views imgt anim type picture doc id sa d a dabd a cb c fae fa cfb width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a dabd a cb c fae fa cfb https login skype com login sso go xmmfallback pic sa d a dabd a cb c fae fa cfb a originalname v screenshot jpg originalname filesize v filesize meta type photo originalname screenshot jpg meta uriobject',
#  'partlist type missed alt callid ccde d aa f d eee dff part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'check this error',
#  'okay',
#  'i need this type of pattern but im getting only last line',
#  'uriobject uri https api asm skype com v objects eus d cd a bd a d fdf d url thumbnail https api asm skype com v objects eus d cd a bd a d fdf d views imgt anim type picture doc id eus d cd a bd a d fdf d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic eus d cd a bd a d fdf d https login skype com login sso go xmmfallback pic eus d cd a bd a d fdf d a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'should i put the code of lambda function there',
#  'hi',
#  'uriobject type picture uri https api asm skype com v objects sa d e bc fc aed b c fec bbd url thumbnail https api asm skype com v objects sa d e bc fc aed b c fec bbd views imgt title title description description a href https login skype com login sso go xmmfallback pic sa d e bc fc aed b c fec bbd https login skype com login sso go xmmfallback pic sa d e bc fc aed b c fec bbd a originalname v c users dell appdata local packages microsoft skypeapp kzf qxf zg c localstate a e bf f d edfc e jpg meta type photo originalname c users dell appdata local packages microsoft skypeapp kzf qxf zg c localstate a e bf f d edfc e jpg uriobject',
#  'thanx again for your concern in this hour',
#  'partlist type missed alt callid f b d c a bdcc part identity live cibim name cibi m name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'pattern is not properly coming',
#  'got it sir it suppose to be double equal to i have put it one',
#  'its working fine',
#  'am getting',
#  'hello sir is there any one',
#  'this link data is ok but item name is not able to manipulate',
#  'hi',
#  'th jan recording',
#  'i have created new environment now and then this problem came',
#  'uriobject uri https api asm skype com v objects ea d a d de b fd f c e url thumbnail https api asm skype com v objects ea d a d de b fd f c e views imgt anim type picture doc id ea d a d de b fd f c e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic ea d a d de b fd f c e https login skype com login sso go xmmfallback pic ea d a d de b fd f c e a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'i got an email it has been already evaluated',
#  'hi',
#  'actually i followed and execute one code',
#  'hello',
#  'i have sended yesterday',
#  'just you go with download page',
#  'its taking much time now',
#  'hi',
#  'oh ey hows it going',
#  'please provide some solution',
#  'but sir can apos t i work without gcp it is asking card details',
#  'sir how to remove this error',
#  'uriobject uri https api asm skype com v objects sa d cb b bb c c d a a url thumbnail https api asm skype com v objects sa d cb b bb c c d a a views imgt anim type picture doc id sa d cb b bb c c d a a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d cb b bb c c d a a https login skype com login sso go xmmfallback pic sa d cb b bb c c d a a a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'my test dataset selected through random sampling gives better result than that selected through stratified sampling',
#  'uriobject uri https api asm skype com v objects sa d c bd ff c b ad f url thumbnail https api asm skype com v objects sa d c bd ff c b ad f views imgt anim type picture doc id sa d c bd ff c b ad f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c bd ff c b ad f https login skype com login sso go xmmfallback pic sa d c bd ff c b ad f a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'total or',
#  'its running now thanx',
#  'please help',
#  'uriobject uri https api asm skype com v objects sa d ac bea df ec fe f a e url thumbnail https api asm skype com v objects sa d ac bea df ec fe f a e views imgt anim type picture doc id sa d ac bea df ec fe f a e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ac bea df ec fe f a e https login skype com login sso go xmmfallback pic sa d ac bea df ec fe f a e a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'hello',
#  'return avg ampl np cos times time offset np pi times max',
#  'in which sector is there a good need of data scientist',
#  'ill send u the screen shot',
#  'i apos m getting this error after running the complete code is it because i have created the project in d drive',
#  'can u tell me exactly how it will differentitae',
#  'how about the projects',
#  'thank you sir',
#  'but its not giving the value',
#  'yes sir',
#  'thank you ss type smile ss',
#  'hi',
#  'this is my data set',
#  'hi',
#  'ss type sad ss',
#  'ok sir',
#  'ok',
#  'sir i have registered for powerbi module not for python yet could please tell me the process so that i can do it at the earliest thanks',
#  'uriobject uri https api asm skype com v objects sa d e b f efc eab e bb a url thumbnail https api asm skype com v objects sa d e b f efc eab e bb a views imgt anim type picture doc id sa d e b f efc eab e bb a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e b f efc eab e bb a https login skype com login sso go xmmfallback pic sa d e b f efc eab e bb a a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'but in local system it shows same error',
#  'thank you',
#  'uriobject uri https api asm skype com v objects sa d d ab bfaac fdd fd e a b ce url thumbnail https api asm skype com v objects sa d d ab bfaac fdd fd e a b ce views imgt anim type picture doc id sa d d ab bfaac fdd fd e a b ce width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d ab bfaac fdd fd e a b ce https login skype com login sso go xmmfallback pic sa d d ab bfaac fdd fd e a b ce a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'but if i want output of the specific batsman how many times he has been dismissed then what should i do sir',
#  'uriobject uri https api asm skype com v objects sa d be d b a b ea acb b url thumbnail https api asm skype com v objects sa d be d b a b ea acb b views imgt anim type picture doc id sa d be d b a b ea acb b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d be d b a b ea acb b https login skype com login sso go xmmfallback pic sa d be d b a b ea acb b a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#  'uriobject uri https api asm skype com v objects sa d a a d b a d f b url thumbnail https api asm skype com v objects sa d a a d b a d f b views imgt anim type picture doc id sa d a a d b a d f b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a a d b a d f b https login skype com login sso go xmmfallback pic sa d a a d b a d f b a originalname v picturemessage sjrvccr gvd png originalname filesize v filesize meta type photo originalname picturemessage sjrvccr gvd png meta uriobject',
#  'hi',
#  'thank you sir',
#  'a href https github com jiwitesh imagescrapper blob master imagescrapper scraper py https github com jiwitesh imagescrapper blob master imagescrapper scraper py a',
#  'uriobject uri https api asm skype com v objects sa d b b cd d d e ab f url thumbnail https api asm skype com v objects sa d b b cd d d e ab f views imgt anim type picture doc id sa d b b cd d d e ab f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b b cd d d e ab f https login skype com login sso go xmmfallback pic sa d b b cd d d e ab f a originalname v screenshot from png originalname filesize v filesize meta type photo originalname screenshot from png meta uriobject',
#  'partlist type missed alt oid a a de d db c part identity live bcf e b d name anil taninki name part part identity live cid a bf name support ineuron ai name part partlist',
#  'how to solve this issue i tried every thing but no result',
#  'ss type hi wave ss',
#  'hello sir i am from mldl th june batch and dlcvnpl th july batch i have applied for internship but after attending yesterday s session i dont think i am ready for the internship so if my name is enrolled for internship kindly post it to next internship',
#  'sure',
#  'can you sujjest me some sites name other than flipkart',
#  'actually i implemented it separately',
#  'partlist type missed alt callid ccde d aa f d eee dff part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'sir in this line what basically and p doing',
#  'am getting',
#  'partlist type ended alt callid b b ce ff db b a e bbd e part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#  'hi',
#  'uriobject uri https api asm skype com v objects sa d ae b a e adb f be e url thumbnail https api asm skype com v objects sa d ae b a e adb f be e views imgt anim type picture doc id sa d ae b a e adb f be e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ae b a e adb f be e https login skype com login sso go xmmfallback pic sa d ae b a e adb f be e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#  'thank you sir',
#  'okay i will try',
#  'the name is same for both the files i think',
#  'i apos m just asking for learning purposes',
#  'i already had python skills just want to bursh up my machine learning skills like eda nd machine learning models',
#  'okay',
#  'uriobject uri https api asm skype com v objects sa d ff fe c e ebfa e d e a url thumbnail https api asm skype com v objects sa d ff fe c e ebfa e d e a views imgt anim type picture doc id sa d ff fe c e ebfa e d e a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ff fe c e ebfa e d e a https login skype com login sso go xmmfallback pic sa d ff fe c e ebfa e d e a a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#  'i have a doubt regarding this mail',
#  'here submit assignment button is not available',
#  'thanks',
#  'not recognised anything',
#  'can i send the problem statement and my code here',
#  'ok got it',
#  'this is just a coding doubt rather than a dataset wise doubt',
#  'cheers',
#  'i am telling pdf only',
#  'hii',
#  'yes but i think when u said that string is immutable it can be mutable through converting it into list and then back to tuples',
#  'sir i have changed that and that worked but still my main py is red',
#  'uriobject type picture uri https api asm skype com v objects sa d d a f url thumbnail https api asm skype com v objects sa d d a f views imgt to view this shared photo go to a href https login skype com login sso go xmmfallback amp pic sa d d a f https login skype com login sso go xmmfallback amp pic sa d d a f a originalname v img jpg filesize v meta type photo originalname img jpg uriobject',
#  'hi',
#  'no thank you i got it',
#  'could you please help me with this',
#  'sir instead of python i can use only python',
#  'uriobject uri https api asm skype com v objects sa d e b ede abba edb e ca b url thumbnail https api asm skype com v objects sa d e b ede abba edb e ca b views imgt anim type picture doc id sa d e b ede abba edb e ca b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e b ede abba edb e ca b https login skype com login sso go xmmfallback pic sa d e b ede abba edb e ca b a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'yes but i think when u said that string is immutable it can be mutable through converting it into list and then back to tuples',
#  'sir my python version is and need scikit learn for my project which is incompatible with python so what should i do',
#  'how to convert this in jupiter notebook',
#  'hello sir',
#  'sir when i m trying to run main py it is showing method object is not subscriptable what does this means can u tell me sir',
#  'hi',
#  'sure',
#  'ok sir',
#  'hello support team',
#  'uriobject uri https api asm skype com v objects sa d dd f e a fb c f d url thumbnail https api asm skype com v objects sa d dd f e a fb c f d views imgt anim type picture doc id sa d dd f e a fb c f d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d dd f e a fb c f d https login skype com login sso go xmmfallback pic sa d dd f e a fb c f d a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#  'thank you sir',
#  'hi sir',
#  ...]

# %%
custom_data1=[] 
#Iterate the tweets 
for data in ticket_df:
  custom_data1.append(store)

# %%
custom_data1
# Out:
# [['sir i created a new env with python but the library for which i got error quot mkl random quot is not compatible with python',
#   'above problem how will it solve',
#   'hello sir is there anyone',
#   'i think canvas login problem was due to browser i tried in chrome and it worked',
#   'understood',
#   'tq',
#   'so ill just copy paste what i wanted to know',
#   'sir any sujjestion to overcome this error',
#   'np random choice apos goal area apos apos goal line apos p',
#   'uriobject uri https api asm skype com v objects sa d b f eebb e c d b d url thumbnail https api asm skype com v objects sa d b f eebb e c d b d views imgt anim type picture doc id sa d b f eebb e c d b d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b f eebb e c d b d https login skype com login sso go xmmfallback pic sa d b f eebb e c d b d a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'i applied for python in depth and power bi course i am yet to get access to dashboard could you please take care',
#   'ok can you check and tell me my registered id is a href mailto paragjp gmail com paragjp gmail com a and register mobile no is',
#   'mediaalbum albumid edcfcd f f ae f b dc a mediaalbum',
#   'uriobject uri https api asm skype com v objects sa d f f ed d b a b url thumbnail https api asm skype com v objects sa d f f ed d b a b views imgt anim type picture doc id sa d f f ed d b a b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f f ed d b a b https login skype com login sso go xmmfallback pic sa d f f ed d b a b a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'how to open terminal from the project folder to execute the git command',
#   'actually i am pursuing my msc in data analytics i was having bootcamp during the weekend hence i couldn apos t attend the classes on th and th oct now i apos m going through the recordings i feel so confident after attending the trainings from ineuron thank you so much',
#   'thank you',
#   'because sentimental analysis is highly co related to brand awreness and hence i want to multiply it with every variable so plz guide me or enlighten me if am doing wrong',
#   'hi',
#   'it will not show anything for download',
#   'in same way i tried to execute another one and getting this issue',
#   'i am shiva from course ml ndfeb batch',
#   'hi',
#   'thank you so much',
#   'okay thank you ss type smile ss',
#   'sir my internship meeting is tomorrow and those who ll not attend will not go further but i requested many times through mail and this medium that i have a family function in rural area so i may not be able to attend the session so i asked to pls suggest me whether i should cancel the trip or not but no response was given and now i m in a rural area and i need atleast days to move from here as transport problem is there so what should i do will i lose my internship chance',
#   'oh thank you not jus one i hope all of my assignments will be viewd n evaluated successfully',
#   'hello sir is there anyone',
#   'please enroll me for the next internship i would be great favor',
#   'still getting the same error',
#   'hi',
#   'done sir connected',
#   'hello sir i would like to know when will next batch of intern will start',
#   'sir i think my file is also ok just the point is url is showing incorrect',
#   'how to install all package in pycharm',
#   'i received an email from ineuron about an internship can you explain about the internship i have not completed the course and what is the skill of doing an internship and how many months it will be taken to complete the internship',
#   'okay',
#   'partlist type started alt callid c b d da afd f a b f part identity live cid b eb e name saritha jaligama name part part identity live cid a bf name support ineuron ai name part partlist',
#   'ok sir',
#   'thanks',
#   'uriobject uri https api asm skype com v objects sa d e ee a d d c f fc d d url thumbnail https api asm skype com v objects sa d e ee a d d c f fc d d views imgt anim type picture doc id sa d e ee a d d c f fc d d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e ee a d d c f fc d d https login skype com login sso go xmmfallback pic sa d e ee a d d c f fc d d a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'if i wrote a flask program where can i see the output e m a live cid b eb e ts ms ts t e m',
#   'uriobject uri https api asm skype com v objects sa d d b dbc cfb b dd a f url thumbnail https api asm skype com v objects sa d d b dbc cfb b dd a f views imgt anim type picture doc id sa d d b dbc cfb b dd a f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d b dbc cfb b dd a f https login skype com login sso go xmmfallback pic sa d d b dbc cfb b dd a f a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'ok',
#   'thank you sir',
#   'hello sir',
#   'yes same env is there',
#   'ok sir',
#   'thnx',
#   'but i was just curious what was the use of that code here',
#   'uriobject uri https api asm skype com v objects cus d dca ee f d f de e url thumbnail https api asm skype com v objects cus d dca ee f d f de e views imgt anim type picture doc id cus d dca ee f d f de e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic cus d dca ee f d f de e https login skype com login sso go xmmfallback pic cus d dca ee f d f de e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'since the beginning of the class',
#   'already done',
#   'have did that also',
#   'ok please let me check',
#   'i have send it again could you please check it',
#   'please check',
#   'got it',
#   'how to fix it',
#   'hii sir',
#   'could you please have a look at it',
#   'i need some advice and guidance from you my apologies for bothering you with these frivolous questions',
#   'but i am getting a error so could you please help me to resolve this error',
#   'uriobject uri https api asm skype com v objects sa d f bedb e c d c fd fef url thumbnail https api asm skype com v objects sa d f bedb e c d c fd fef views imgt anim type picture doc id sa d f bedb e c d c fd fef width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f bedb e c d c fd fef https login skype com login sso go xmmfallback pic sa d f bedb e c d c fd fef a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'yes i got dashboard',
#   'ohh sorry',
#   'it is showing invalid syntex error',
#   'okay thank you',
#   'hi',
#   'sorry is this sudhanshu sir',
#   'file quot lt ipython input ce bc gt quot line print scipy stats ttest ind rvs rvs syntaxerror invalid syntax',
#   'i have taken a dataset on google review from the uci i am going to do on this sir',
#   'what is auto scaling i don apos t know',
#   'uriobject uri https api asm skype com v objects sa d a ab bee a e e ee d url thumbnail https api asm skype com v objects sa d a ab bee a e e ee d views imgt anim type picture doc id sa d a ab bee a e e ee d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a ab bee a e e ee d https login skype com login sso go xmmfallback pic sa d a ab bee a e e ee d a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'sirr what to do for mkl random',
#   'please fix this issue asap',
#   'good morning',
#   'sir was ping to chat box',
#   'uriobject uri https api asm skype com v objects sa d ae bc c b e e ba f url thumbnail https api asm skype com v objects sa d ae bc c b e e ba f views imgt anim type picture doc id sa d ae bc c b e e ba f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ae bc c b e e ba f https login skype com login sso go xmmfallback pic sa d ae bc c b e e ba f a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d ff b f e ab e f url thumbnail https api asm skype com v objects sa d ff b f e ab e f views imgt anim type picture doc id sa d ff b f e ab e f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ff b f e ab e f https login skype com login sso go xmmfallback pic sa d ff b f e ab e f a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'is machine learning a pre requisite',
#   'hi',
#   'hi',
#   'i want to replace non values in not rated',
#   'hi',
#   'uriobject uri https api asm skype com v objects sa d fe aeab ef c b fe f c url thumbnail https api asm skype com v objects sa d fe aeab ef c b fe f c views imgt anim type picture doc id sa d fe aeab ef c b fe f c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d fe aeab ef c b fe f c https login skype com login sso go xmmfallback pic sa d fe aeab ef c b fe f c a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d d c c c d d ef c bfbd url thumbnail https api asm skype com v objects sa d d c c c d d ef c bfbd views imgt anim type picture doc id sa d d c c c d d ef c bfbd width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d c c c d d ef c bfbd https login skype com login sso go xmmfallback pic sa d d c c c d d ef c bfbd a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'thank you so much',
#   'ok',
#   'mediaalbum albumid f ac d ea dbfdcb mediaalbum',
#   'i will restart the system and reinstall again',
#   'got timeout seconds error',
#   'uriobject uri https api asm skype com v objects sa d c a cb ad f f bbb url thumbnail https api asm skype com v objects sa d c a cb ad f f bbb views imgt anim type picture doc id sa d c a cb ad f f bbb width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c a cb ad f f bbb https login skype com login sso go xmmfallback pic sa d c a cb ad f f bbb a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'hi',
#   'bad gateway',
#   'no problem',
#   'but would u happen to knw when can i get in touch with sudhanshu sir through this mode of comm',
#   'so they are asking professional email id',
#   'can you please tell me how to opt out from this internship',
#   'hi',
#   'sir i used this password',
#   'sir by using forward fill how i increase the value by',
#   'how does it solve',
#   'sorry i understood output matrix and tried that i need second question explanation',
#   'uriobject uri https api asm skype com v objects sa d ca f c abcf f ca ba c url thumbnail https api asm skype com v objects sa d ca f c abcf f ca ba c views imgt anim type picture doc id sa d ca f c abcf f ca ba c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ca f c abcf f ca ba c https login skype com login sso go xmmfallback pic sa d ca f c abcf f ca ba c a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'applying remove blank rows i am still getting null values what could be issue here',
#   'how will it solve',
#   'if you didn apos t understand my problem let me know i send pics',
#   'one doubt from last class power bi it was well explained about to delete the rows having null blank value but how will we be able to delete the rows having values as missing na naan etc we know that these values are not necessary but how to handle these rows in power bi',
#   'its not working properly',
#   'hello good afternoon i apos m avinash student of june ml batch i have applied for internship that is going to start from november',
#   'hii i am vishnu derkar and i have the form for internship on aug but couldn t find my name in the list',
#   'ya i watched more video then got clarified thank you so much',
#   'partlist type ended alt callid bda ecb a e b c b c cfb part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'mediaalbum albumid a f fa e a a mediaalbum',
#   'ok sir',
#   'so what should i do',
#   'ok',
#   'no not a dashboard data set',
#   'hi',
#   'q write a python program with class concepts to find the area of the triangle using the below formula area s s a s b s c function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass class triangle def takeinput a int input quot enter the first side quot b int input quot enter the second side quot c int input quot enter the third side quot return a b c class areatriangle triangle def areatriangle a b c s a b c area s s a s b s c print quot the area of triangle is quot area obj areatriangleres obj takeinput obj areatriangle res res res',
#   'hi',
#   'hello sir is there any one',
#   'thanks',
#   'plz put your input on the file i created',
#   'can you please give me some references from where i can learn about these techniques',
#   'uriobject uri https api asm skype com v objects sa d a efdca df da d f dc f b url thumbnail https api asm skype com v objects sa d a efdca df da d f dc f b views imgt anim type picture doc id sa d a efdca df da d f dc f b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a efdca df da d f dc f b https login skype com login sso go xmmfallback pic sa d a efdca df da d f dc f b a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'let me know the solution',
#   'it worked',
#   'hi',
#   'uriobject uri https api asm skype com v objects sa d c a ea a f bf dfc url thumbnail https api asm skype com v objects sa d c a ea a f bf dfc views imgt anim type picture doc id sa d c a ea a f bf dfc width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c a ea a f bf dfc https login skype com login sso go xmmfallback pic sa d c a ea a f bf dfc a originalname v temp png originalname filesize v filesize meta type photo originalname temp png meta uriobject',
#   'still the same result in both the cases',
#   'sir please check it and tell me whether i can send the nda now if yes then to which mail id',
#   'can i get the python in my dashboard please',
#   'good afternoon sir',
#   'partlist type missed alt oid f fcc b e a f cde cfb part identity live cid b c cf name mukunthan ragavan name part part identity live cid a bf name support ineuron ai name part partlist',
#   'hi',
#   'yes',
#   'great thanks boss',
#   'good work sir',
#   'it is present just checked',
#   'what will happen if we include that column here and what will happen if we don apos t include that',
#   'sir i got the answer it is ok i got it how to solve',
#   'uriobject uri https api asm skype com v objects sa d dbbc fde f e c e b df ebaf url thumbnail https api asm skype com v objects sa d dbbc fde f e c e b df ebaf views imgt anim type picture doc id sa d dbbc fde f e c e b df ebaf width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d dbbc fde f e c e b df ebaf https login skype com login sso go xmmfallback pic sa d dbbc fde f e c e b df ebaf a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'k',
#   'thanks a lot',
#   'but when i write the command mentioned in the screenshot the command greys out',
#   'but there is some filter getting applied',
#   'sure thank u',
#   'hi sir good morning',
#   'hello this is shashidhar',
#   'it is solve its working fine',
#   'thanks',
#   'okay',
#   'i have registered already ok any ways i will wait for the dash board access',
#   'a href https drive google com file d u x nz vqw aypsukbmhfwenitqsgbo view https drive google com file d u x nz vqw aypsukbmhfwenitqsgbo view a',
#   'yup',
#   'to which one',
#   'okay',
#   'uriobject uri https api asm skype com v objects sa d f ab f bd f fc a url thumbnail https api asm skype com v objects sa d f ab f bd f fc a views imgt anim type picture doc id sa d f ab f bd f fc a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f ab f bd f fc a https login skype com login sso go xmmfallback pic sa d f ab f bd f fc a a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'hi',
#   'sure give me a second',
#   'when will the enroll machine learning and deep learning with deployment end',
#   'yes sir',
#   'i can apos t ask doubts there',
#   'sir i have imported it successfully but it is still showing this',
#   'thanks',
#   'datetime not able to change datatype',
#   'so withour anaconda i need to install every thing on my own anaconda is a distribution of all libraries used in data science',
#   'hi',
#   'sir i was just revising again with ur previous video recordings',
#   'hi',
#   'data is titanic',
#   'uriobject uri https api asm skype com v objects sa d a d d db a b a d d url thumbnail https api asm skype com v objects sa d a d d db a b a d d views imgt anim type picture doc id sa d a d d db a b a d d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a d d db a b a d d https login skype com login sso go xmmfallback pic sa d a d d db a b a d d a originalname v final dashbaord image png originalname filesize v filesize meta type photo originalname final dashbaord image png meta uriobject',
#   'okay thankyou',
#   'i was facing this issue in zoom video call yesterday',
#   'i apos m not getting what is wrong with below syntax',
#   'def gen ss type no n ss for i in range n for j in range i print quot quot end quot quot print quot r quot for p in range n n for k in range p print quot quot end quot quot print quot quot end quot quot',
#   'hello sir is there anyone',
#   'see the error please sujest onit',
#   'iplot is not working',
#   'previous chatt just check that one',
#   'class all sentences passtry subjects quot americans quot quot indians quot verbs quot play quot quot watch quot objects quot baseball quot quot cricket quot sentences sub quot quot ver quot quot obj for sub in subjects for ver in verbs for obj in objects except print apos the required statement can not be performed apos print all sentences',
#   'i check the connection',
#   'uriobject uri https api asm skype com v objects sa d f dfdf e e bf c e url thumbnail https api asm skype com v objects sa d f dfdf e e bf c e views imgt anim type picture doc id sa d f dfdf e e bf c e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d f dfdf e e bf c e https login skype com login sso go xmmfallback pic sa d f dfdf e e bf c e a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'seen the above thread its the same procedure i followed',
#   'yes sure sir',
#   'uriobject uri https api asm skype com v objects sa d bf c bddcb aac a a b url thumbnail https api asm skype com v objects sa d bf c bddcb aac a a b views imgt anim type picture doc id sa d bf c bddcb aac a a b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d bf c bddcb aac a a b https login skype com login sso go xmmfallback pic sa d bf c bddcb aac a a b a originalname v picturemessage xdu r q iox png originalname filesize v filesize meta type photo originalname picturemessage xdu r q iox png meta uriobject',
#   'hithis is related to the weeks python trainingi can see that assignment for pandas is available in the module but in the grades section there is no option to submit the pandas assignment',
#   'sir i didnt get it can u tell once again what to do',
#   'uriobject uri https api asm skype com v objects sa d d d bf da c afecb f url thumbnail https api asm skype com v objects sa d d d bf da c afecb f views imgt anim type picture doc id sa d d d bf da c afecb f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d d bf da c afecb f https login skype com login sso go xmmfallback pic sa d d d bf da c afecb f a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'plz help me how can i implement it as single list',
#   'okay will try this and will revert back',
#   'hi',
#   'i also need in laptop',
#   'uriobject uri https api asm skype com v objects sa d c bdeb aebd a c url thumbnail https api asm skype com v objects sa d c bdeb aebd a c views imgt anim type picture doc id sa d c bdeb aebd a c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c bdeb aebd a c https login skype com login sso go xmmfallback pic sa d c bdeb aebd a c a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'i have a dount in one of the datasets',
#   'uriobject type audio message url thumbnail https api asm skype com v objects ea d aedd baa e da f ecee ab views thumbnail uri https api asm skype com v objects ea d aedd baa e da f ecee ab title voicemail title a href https login skype com login sso go webclient xmm amp am ea d aedd baa e da f ecee ab play a originalname v voicemail wav uriobject',
#   'are you there',
#   'thank you',
#   'bro you are not responding my problem since last days',
#   'this is compass interface',
#   'yes i am',
#   'thanks i am able to acess that',
#   'still same error',
#   'ok',
#   'ok',
#   'hello sir is there anyone',
#   'thank you',
#   'uriobject uri https api asm skype com v objects sa d e f a d adb d bd c url thumbnail https api asm skype com v objects sa d e f a d adb d bd c views imgt anim type picture doc id sa d e f a d adb d bd c width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e f a d adb d bd c https login skype com login sso go xmmfallback pic sa d e f a d adb d bd c a originalname v picturemessage o rpuu o txt png originalname filesize v filesize meta type photo originalname picturemessage o rpuu o txt png meta uriobject',
#   'sir i have forgot my canvas password when i clicked forget password it should send me the password but i didn apos t get any mail what should i do',
#   'pls chk this',
#   'as in is it an extension to any of the courses or is it standalone and can be pursued by someone who wants to learn computer vision thank u',
#   'i restarted notebook but sasme error coming',
#   'sir ans is but mine was using this one',
#   'this error is coming',
#   'uriobject uri https api asm skype com v objects sa d ed be ac c d fc d ad url thumbnail https api asm skype com v objects sa d ed be ac c d fc d ad views imgt anim type picture doc id sa d ed be ac c d fc d ad width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ed be ac c d fc d ad https login skype com login sso go xmmfallback pic sa d ed be ac c d fc d ad a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d b d cf fa bb b d e url thumbnail https api asm skype com v objects sa d b d cf fa bb b d e views imgt anim type picture doc id sa d b d cf fa bb b d e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b d cf fa bb b d e https login skype com login sso go xmmfallback pic sa d b d cf fa bb b d e a originalname v picturemessage dgcm ujf e png originalname filesize v filesize meta type photo originalname picturemessage dgcm ujf e png meta uriobject',
#   'i have received mail from sudhanshu to download the course pdf',
#   'i checked multiple time impute function every time it fails when the column name police report available runs into the loop',
#   'partlist type ended alt callid e e bc f c c part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'sir how much calculus is needed in the field of the data science',
#   'but now not able to access it using the same email',
#   'i registered for the dashboard on last tuesday but still i didnt get it so plz provide it',
#   'its already done but failed',
#   'sir can u see that ok option',
#   'hello sir is there anyone',
#   'google colab is online platform so i have given code on there for execution and share link on submit assignment',
#   'uriobject uri https api asm skype com v objects sa d ad e d e bf a url thumbnail https api asm skype com v objects sa d ad e d e bf a views imgt anim type picture doc id sa d ad e d e bf a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ad e d e bf a https login skype com login sso go xmmfallback pic sa d ad e d e bf a a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'i tried but it apos s the same error',
#   'thank you so much',
#   'hello i have subscribed to both pyton and power bi courses but only received access to power bi bit could you give me access to python course as well my email is jose quintini gmail com thanks in advance',
#   'hello sir is there anyone',
#   'partlist type missed alt callid da e a db fa de b f c ea part identity live f de c ca name anshul singh name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'ok',
#   'also if one can become a full stack engineer front and back end on the products developed',
#   'hello sir i have joined the powerbi and tableau course i would like to join your python course as well if possible name kaustavid a href mailto kaustavritwik gmail com kaustavritwik gmail com a looking forward to hearing from you regards',
#   'yes',
#   'ok',
#   'sir u there',
#   'uriobject uri https api asm skype com v objects sa d cc af e d url thumbnail https api asm skype com v objects sa d cc af e d views imgt anim type picture doc id sa d cc af e d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d cc af e d https login skype com login sso go xmmfallback pic sa d cc af e d a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'hi',
#   'uriobject uri https api asm skype com v objects sa d eac dcabd d e f b url thumbnail https api asm skype com v objects sa d eac dcabd d e f b views imgt anim type picture doc id sa d eac dcabd d e f b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d eac dcabd d e f b https login skype com login sso go xmmfallback pic sa d eac dcabd d e f b a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'how to check that sir',
#   'i wanted to ask u something',
#   'sir i understood that',
#   'what you were trying to say sir',
#   'sure sir thank you',
#   'thank you',
#   'hi sir',
#   'ok',
#   'ok',
#   'i will select in those library',
#   'on the first day i had clicked launch meeting in the website and it showed the video call',
#   'how can i avail that',
#   'done sir',
#   'it shows invalid syntax',
#   'bro tell me how will it download',
#   'uriobject uri https api asm skype com v objects sa d db f e fdfbeac d ce url thumbnail https api asm skype com v objects sa d db f e fdfbeac d ce views imgt anim type picture doc id sa d db f e fdfbeac d ce width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d db f e fdfbeac d ce https login skype com login sso go xmmfallback pic sa d db f e fdfbeac d ce a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d a cf bec c bb b d b bd a url thumbnail https api asm skype com v objects sa d a cf bec c bb b d b bd a views imgt anim type picture doc id sa d a cf bec c bb b d b bd a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a cf bec c bb b d b bd a https login skype com login sso go xmmfallback pic sa d a cf bec c bb b d b bd a a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d da f c d a be d e url thumbnail https api asm skype com v objects sa d da f c d a be d e views imgt anim type picture doc id sa d da f c d a be d e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d da f c d a be d e https login skype com login sso go xmmfallback pic sa d da f c d a be d e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'ok',
#   'and submit that snap and this word fill to that mail only',
#   'instead of getting directly i apos m getting step by step procedure e m a kiran menon ts ms ts t e m',
#   'uriobject type picture uri https api asm skype com v objects sa d c d fe ffef e url thumbnail https api asm skype com v objects sa d c d fe ffef e views imgt to view this shared photo go to a href https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e a originalname v screenshot jpg filesize v meta type photo originalname screenshot jpg uriobject',
#   'i will have a look again and try for it',
#   'ss type hi wave ss',
#   'sir this is the dataset',
#   'uriobject uri https api asm skype com v objects sa d a e f a f e c a e b url thumbnail https api asm skype com v objects sa d a e f a f e c a e b views imgt anim type picture doc id sa d a e f a f e c a e b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a e f a f e c a e b https login skype com login sso go xmmfallback pic sa d a e f a f e c a e b a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'java not found and java home environment variable is not set install java and set java home to point to the java installation directory',
#   'ok will do that',
#   'uriobject uri https api asm skype com v objects sa d d bf bf d d abfb a d eab url thumbnail https api asm skype com v objects sa d d bf bf d d abfb a d eab views imgt anim type picture doc id sa d d bf bf d d abfb a d eab width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d bf bf d d abfb a d eab https login skype com login sso go xmmfallback pic sa d d bf bf d d abfb a d eab a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'thank you so much ss type smile ss',
#   'see the environment is same but the chromedriver is showing different',
#   'thanks for your help the issue has now been resolved',
#   'uriobject uri https api asm skype com v objects sa d be bb d cd fd df e c e url thumbnail https api asm skype com v objects sa d be bb d cd fd df e c e views imgt anim type picture doc id sa d be bb d cd fd df e c e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d be bb d cd fd df e c e https login skype com login sso go xmmfallback pic sa d be bb d cd fd df e c e a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'ok',
#   'so can you tell exact video or any link gt gt',
#   'uriobject uri https api asm skype com v objects sa d a bd f e a aec b bb b url thumbnail https api asm skype com v objects sa d a bd f e a aec b bb b views imgt anim type picture doc id sa d a bd f e a aec b bb b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a bd f e a aec b bb b https login skype com login sso go xmmfallback pic sa d a bd f e a aec b bb b a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'but sometime i am not able to understand code what should i do whatever you given as a support',
#   'ok sir',
#   'that apos s why i apos m requesting you sir',
#   'gr tks',
#   'i am sorry for posting silly issues i was engrossed in the code that i couldn apos t locate for the mistake',
#   'already registered but my dash board didn t get updated',
#   'the latest internship of august which i m supposed to join but failed to join the meeting that day',
#   'sir how can we remove this error',
#   'how to raise a ticket',
#   'kindly accept my invitation',
#   'sir so what is the final call is it ok if i don apos t attend tomorrow meeting will get a chance after our course completion',
#   'one more point is i am a mech engineer student and passed out in from then i was preparing for ies so i don apos t have any experience yet and a gap of years so will i be able to get the job inspite of the gap',
#   'thank you',
#   'yes',
#   'uriobject uri https api asm skype com v objects sa d cdd fa e d e e e url thumbnail https api asm skype com v objects sa d cdd fa e d e e e views imgt anim type picture doc id sa d cdd fa e d e e e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d cdd fa e d e e e https login skype com login sso go xmmfallback pic sa d cdd fa e d e e e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d c e d e e e d url thumbnail https api asm skype com v objects sa d c e d e e e d views imgt anim type picture doc id sa d c e d e e e d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c e d e e e d https login skype com login sso go xmmfallback pic sa d c e d e e e d a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'for instance if i need to find the stability of an ship after stacking the containers in it may i know what kind of model will be gud to find the stability of the ship plz suggest me an eqn of it too plzzz',
#   'i installed flask in anaconda prompt and then i imported flask in jpyter and i wrote simple hello world program now i want to see the location by cmd but im not getting the location',
#   'its working properly',
#   'i was trying to create a greeting card with python coding with the help of a youtube video i did everything same but still getting an error',
#   'hi',
#   'uriobject uri https api asm skype com v objects sa d c ae f c d b f url thumbnail https api asm skype com v objects sa d c ae f c d b f views imgt anim type picture doc id sa d c ae f c d b f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c ae f c d b f https login skype com login sso go xmmfallback pic sa d c ae f c d b f a originalname v step size doubt jpg originalname filesize v filesize meta type photo originalname step size doubt jpg meta uriobject',
#   'is the code right',
#   'ohk sir thank you',
#   'no am asking as a service i just want to know is there someone that yu can connect with mee',
#   'yes i have published it',
#   'okay',
#   'okay',
#   'can u help me on this',
#   'yes sir',
#   'can we use class operation as i have shown',
#   'the columns which i want to select is latitude and longitude so i can do that bcs i want the row which had highest latitude along with latitude and longitude i made a groupby on country country has multiple occurrences in the dataset',
#   'mediaalbum albumid a a d d a f d mediaalbum',
#   'uriobject uri https api asm skype com v objects sa d c aaa f f c cbf url thumbnail https api asm skype com v objects sa d c aaa f f c cbf views imgt anim type picture doc id sa d c aaa f f c cbf width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c aaa f f c cbf https login skype com login sso go xmmfallback pic sa d c aaa f f c cbf a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'but how much time it would it take to get a job as a data scientist as i graduated from bba',
#   'failed',
#   'but how to train the model about my application which we are testingwhat will be the data for my model to train',
#   'ok sir actually i have submitted my first assignment from assignment section',
#   'cheers',
#   'yaa sure',
#   'partlist type missed alt oid c ee d d a de f e part identity live charkhe aniket name aniket charkhe name part part identity live cid a bf name support ineuron ai name part partlist',
#   'hi',
#   'got it sir',
#   'ok',
#   'thats fanstastic sir thank u for making it easy for me i will pay it before the start of the second week of the lecture',
#   'i followed two times but in video its working properly here it getting error',
#   'thank you',
#   'sir i change the setting of the browser then i opened it again',
#   'uriobject uri https api asm skype com v objects sa d c dde ad e db fa url thumbnail https api asm skype com v objects sa d c dde ad e db fa views imgt anim type picture doc id sa d c dde ad e db fa width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c dde ad e db fa https login skype com login sso go xmmfallback pic sa d c dde ad e db fa a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'uriobject type picture uri https api asm skype com v objects sa d c d fe ffef e url thumbnail https api asm skype com v objects sa d c d fe ffef e views imgt to view this shared photo go to a href https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e https login skype com login sso go xmmfallback amp pic sa d c d fe ffef e a originalname v screenshot jpg filesize v meta type photo originalname screenshot jpg uriobject',
#   'sir this is rd question i am asking nd one',
#   'uriobject uri https api asm skype com v objects sa d d f a b b a aca url thumbnail https api asm skype com v objects sa d d f a b b a aca views imgt anim type picture doc id sa d d f a b b a aca width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d f a b b a aca https login skype com login sso go xmmfallback pic sa d d f a b b a aca a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'sir i would like to know how the tableau and power bi helps the mba fellow in his career',
#   'tried the same in colab also',
#   'uriobject type file uri https api asm skype com v objects sa d f a e accbfafb a a d url thumbnail https api asm skype com v objects sa d f a e accbfafb a a d views thumbnail title title ndadoc docx title description description ndadoc docx description a href https login skype com login sso go xmmfallback amp docid sa d f a e accbfafb a a d https login skype com login sso go xmmfallback amp docid sa d f a e accbfafb a a d a originalname v ndadoc docx filesize v uriobject',
#   'ok but its been more than days and yet not able to solve',
#   'uriobject uri https api asm skype com v objects sa d b bbfb bf ba f fe e url thumbnail https api asm skype com v objects sa d b bbfb bf ba f fe e views imgt anim type picture doc id sa d b bbfb bf ba f fe e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b bbfb bf ba f fe e https login skype com login sso go xmmfallback pic sa d b bbfb bf ba f fe e a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'yes sir',
#   'no sir i want to know the names of batsman with sixes they have hitted till yet',
#   'i am from ml batch can you tell me from when new internship will begin so that i can enroll for it',
#   'thank you',
#   'uriobject uri https api asm skype com v objects sa d b a f d a d d f d f url thumbnail https api asm skype com v objects sa d b a f d a d d f d f views imgt anim type picture doc id sa d b a f d a d d f d f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b a f d a d d f d f https login skype com login sso go xmmfallback pic sa d b a f d a d d f d f a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'i created new username and password',
#   'yes',
#   'am sending',
#   'ss type hi wave ss',
#   'find a list within a list and then reverse all the strings within that list then in the reversed list reverse all the characters of the string in that list',
#   'hi',
#   'ok thank you',
#   'we have to save assignment in public or private',
#   'sir i am not able to understand the problem statement sir by looking at context and content sir',
#   'also can u share the ppt slide he mentioned',
#   'i received the mail regarding the internship letter',
#   'create the below pattern using nested for loop in python',
#   'i have a dount in one of the datasets',
#   'i have enrolled for python as well yesterday but couldn t see them in dashboard hope its in progress',
#   'nd wt is the exact status of that batch like wt s learning point they are at',
#   'please see it once',
#   'hello sir can you suggest which domain i should choose for internship i am student year exp wants to get job quickly and good package which domain would you suggest',
#   'thank you',
#   'okay will try this now',
#   'uriobject uri https api asm skype com v objects sa d e b cee e cf b url thumbnail https api asm skype com v objects sa d e b cee e cf b views original type file doc id sa d e b cee e cf b to view this file go to a href https login skype com login sso go webclient xmm amp docid sa d e b cee e cf b https login skype com login sso go webclient xmm amp docid sa d e b cee e cf b a originalname v untitled png originalname filesize v filesize uriobject',
#   'uriobject uri https api asm skype com v objects sa d b b b e b e bbda url thumbnail https api asm skype com v objects sa d b b b e b e bbda views imgt anim type picture doc id sa d b b b e b e bbda width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b b b e b e bbda https login skype com login sso go xmmfallback pic sa d b b b e b e bbda a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'i am new to the zoom call',
#   'and also i have registered before days and again i have registered today as well',
#   'ss type smile ss',
#   'this code here',
#   'ok thanks',
#   'because if it is for statistics we haven apos t started it yet',
#   'uriobject uri https api asm skype com v objects ea d fbb fb bfbdbfe a cefde url thumbnail https api asm skype com v objects ea d fbb fb bfbdbfe a cefde views original type file doc id ea d fbb fb bfbdbfe a cefde to view this file go to a href https login skype com login sso go webclient xmm amp docid ea d fbb fb bfbdbfe a cefde https login skype com login sso go webclient xmm amp docid ea d fbb fb bfbdbfe a cefde a originalname v bai docx originalname filesize v filesize uriobject',
#   'hihow shall i submit my assignment on the dashboard i have completed my assignment which was given yesterday but i apos m not able to figure out how to submit it could you please help me with this',
#   'ok thanks sir',
#   'mediaalbum albumid ad c ea ad fcf efead a mediaalbum',
#   'sir this project is reviewscrapper i was watching recorded video also and just finished it',
#   'fine',
#   'still getting the authentication error',
#   'where is blog link',
#   'yes',
#   'partlist type started alt oid f ec df e b d d part identity live cid fe b b c f name vikash singh name part part identity live cid a bf name support ineueon ai name part partlist',
#   'hi there',
#   'ss type hi wave ss',
#   'uriobject uri https api asm skype com v objects sa d bd d e b fb be a url thumbnail https api asm skype com v objects sa d bd d e b fb be a views imgt anim type picture doc id sa d bd d e b fb be a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d bd d e b fb be a https login skype com login sso go xmmfallback pic sa d bd d e b fb be a a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'partlist type missed alt callid d aa c d a b b a d a part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'i have this one',
#   'it worked',
#   'how can i do that sir any suggestions',
#   'no i need an internship and i don apos t have that much time to wait till jan and i have basic knowledge in machine learning and deep learning for clear understanding i joined ineuron',
#   'hi',
#   'sir after passing pip install r requirements txt',
#   'hello',
#   'uriobject uri https api asm skype com v objects sa d ea a bee e b f a fb cc url thumbnail https api asm skype com v objects sa d ea a bee e b f a fb cc views imgt anim type picture doc id sa d ea a bee e b f a fb cc width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ea a bee e b f a fb cc https login skype com login sso go xmmfallback pic sa d ea a bee e b f a fb cc a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'okay thanks',
#   'hi',
#   'and my output on python is apos ruu apos',
#   'any web invite will be send to mail or in canvas how to join',
#   'but the url which i entered is correct right',
#   'hi',
#   'partlist type ended alt callid bbc a ee b f f a d part identity live cibim name cibi m name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'for python will it show in ineuron channel',
#   'in today apos s class i got to know that we shall submit our assignments via google colab i have already submitted few assignments related to mldl th june batch via github url will it be okay',
#   'still not opening sir',
#   'u there',
#   'ok sir i am reinstalling evry thing now',
#   'yes sir',
#   'k sir will get back to you',
#   'i have applied for a job',
#   'i am in my bca final year sir currently',
#   'i will check if i can connect with the registered email which is with canvas',
#   'partlist type missed alt callid c e e a a d db f c part identity live cid f name sarthak awasthi name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
# ...
#   'i am waiting np',
#   'leave it',
#   'uriobject uri https api asm skype com v objects sa d c a d f b dd d e d ae url thumbnail https api asm skype com v objects sa d c a d f b dd d e d ae views imgt anim type picture doc id sa d c a d f b dd d e d ae width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c a d f b dd d e d ae https login skype com login sso go xmmfallback pic sa d c a d f b dd d e d ae a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'can i have the link please',
#   'code that i have written',
#   'bro understand but file is not running now',
#   'to make it simple to understand for an input keyword i need to collect extract certain features like views clicks impressions ctr etc',
#   'file name exactly i dont know just u check file name sometimes file run or some time getting error',
#   'yes sure sir i will',
#   'bro',
#   'okay',
#   'hi sir can i submit the assignments by this week end',
#   'hi',
#   'is this an internship meeting',
#   'i have register to the python for data science yesterday but still not it on the canvas dashboard a href mailto hiranf yahoo com hiranf yahoo com a',
#   'uriobject uri https api asm skype com v objects sa d a dabd a cb c fae fa cfb url thumbnail https api asm skype com v objects sa d a dabd a cb c fae fa cfb views imgt anim type picture doc id sa d a dabd a cb c fae fa cfb width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a dabd a cb c fae fa cfb https login skype com login sso go xmmfallback pic sa d a dabd a cb c fae fa cfb a originalname v screenshot jpg originalname filesize v filesize meta type photo originalname screenshot jpg meta uriobject',
#   'partlist type missed alt callid ccde d aa f d eee dff part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'check this error',
#   'okay',
#   'i need this type of pattern but im getting only last line',
#   'uriobject uri https api asm skype com v objects eus d cd a bd a d fdf d url thumbnail https api asm skype com v objects eus d cd a bd a d fdf d views imgt anim type picture doc id eus d cd a bd a d fdf d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic eus d cd a bd a d fdf d https login skype com login sso go xmmfallback pic eus d cd a bd a d fdf d a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'should i put the code of lambda function there',
#   'hi',
#   'uriobject type picture uri https api asm skype com v objects sa d e bc fc aed b c fec bbd url thumbnail https api asm skype com v objects sa d e bc fc aed b c fec bbd views imgt title title description description a href https login skype com login sso go xmmfallback pic sa d e bc fc aed b c fec bbd https login skype com login sso go xmmfallback pic sa d e bc fc aed b c fec bbd a originalname v c users dell appdata local packages microsoft skypeapp kzf qxf zg c localstate a e bf f d edfc e jpg meta type photo originalname c users dell appdata local packages microsoft skypeapp kzf qxf zg c localstate a e bf f d edfc e jpg uriobject',
#   'thanx again for your concern in this hour',
#   'partlist type missed alt callid f b d c a bdcc part identity live cibim name cibi m name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'pattern is not properly coming',
#   'got it sir it suppose to be double equal to i have put it one',
#   'its working fine',
#   'am getting',
#   'hello sir is there any one',
#   'this link data is ok but item name is not able to manipulate',
#   'hi',
#   'th jan recording',
#   'i have created new environment now and then this problem came',
#   'uriobject uri https api asm skype com v objects ea d a d de b fd f c e url thumbnail https api asm skype com v objects ea d a d de b fd f c e views imgt anim type picture doc id ea d a d de b fd f c e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic ea d a d de b fd f c e https login skype com login sso go xmmfallback pic ea d a d de b fd f c e a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'i got an email it has been already evaluated',
#   'hi',
#   'actually i followed and execute one code',
#   'hello',
#   'i have sended yesterday',
#   'just you go with download page',
#   'its taking much time now',
#   'hi',
#   'oh ey hows it going',
#   'please provide some solution',
#   'but sir can apos t i work without gcp it is asking card details',
#   'sir how to remove this error',
#   'uriobject uri https api asm skype com v objects sa d cb b bb c c d a a url thumbnail https api asm skype com v objects sa d cb b bb c c d a a views imgt anim type picture doc id sa d cb b bb c c d a a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d cb b bb c c d a a https login skype com login sso go xmmfallback pic sa d cb b bb c c d a a a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'my test dataset selected through random sampling gives better result than that selected through stratified sampling',
#   'uriobject uri https api asm skype com v objects sa d c bd ff c b ad f url thumbnail https api asm skype com v objects sa d c bd ff c b ad f views imgt anim type picture doc id sa d c bd ff c b ad f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d c bd ff c b ad f https login skype com login sso go xmmfallback pic sa d c bd ff c b ad f a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'total or',
#   'its running now thanx',
#   'please help',
#   'uriobject uri https api asm skype com v objects sa d ac bea df ec fe f a e url thumbnail https api asm skype com v objects sa d ac bea df ec fe f a e views imgt anim type picture doc id sa d ac bea df ec fe f a e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ac bea df ec fe f a e https login skype com login sso go xmmfallback pic sa d ac bea df ec fe f a e a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'hello',
#   'return avg ampl np cos times time offset np pi times max',
#   'in which sector is there a good need of data scientist',
#   'ill send u the screen shot',
#   'i apos m getting this error after running the complete code is it because i have created the project in d drive',
#   'can u tell me exactly how it will differentitae',
#   'how about the projects',
#   'thank you sir',
#   'but its not giving the value',
#   'yes sir',
#   'thank you ss type smile ss',
#   'hi',
#   'this is my data set',
#   'hi',
#   'ss type sad ss',
#   'ok sir',
#   'ok',
#   'sir i have registered for powerbi module not for python yet could please tell me the process so that i can do it at the earliest thanks',
#   'uriobject uri https api asm skype com v objects sa d e b f efc eab e bb a url thumbnail https api asm skype com v objects sa d e b f efc eab e bb a views imgt anim type picture doc id sa d e b f efc eab e bb a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e b f efc eab e bb a https login skype com login sso go xmmfallback pic sa d e b f efc eab e bb a a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'but in local system it shows same error',
#   'thank you',
#   'uriobject uri https api asm skype com v objects sa d d ab bfaac fdd fd e a b ce url thumbnail https api asm skype com v objects sa d d ab bfaac fdd fd e a b ce views imgt anim type picture doc id sa d d ab bfaac fdd fd e a b ce width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d d ab bfaac fdd fd e a b ce https login skype com login sso go xmmfallback pic sa d d ab bfaac fdd fd e a b ce a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'but if i want output of the specific batsman how many times he has been dismissed then what should i do sir',
#   'uriobject uri https api asm skype com v objects sa d be d b a b ea acb b url thumbnail https api asm skype com v objects sa d be d b a b ea acb b views imgt anim type picture doc id sa d be d b a b ea acb b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d be d b a b ea acb b https login skype com login sso go xmmfallback pic sa d be d b a b ea acb b a originalname v screenshot png originalname filesize v filesize meta type photo originalname screenshot png meta uriobject',
#   'uriobject uri https api asm skype com v objects sa d a a d b a d f b url thumbnail https api asm skype com v objects sa d a a d b a d f b views imgt anim type picture doc id sa d a a d b a d f b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d a a d b a d f b https login skype com login sso go xmmfallback pic sa d a a d b a d f b a originalname v picturemessage sjrvccr gvd png originalname filesize v filesize meta type photo originalname picturemessage sjrvccr gvd png meta uriobject',
#   'hi',
#   'thank you sir',
#   'a href https github com jiwitesh imagescrapper blob master imagescrapper scraper py https github com jiwitesh imagescrapper blob master imagescrapper scraper py a',
#   'uriobject uri https api asm skype com v objects sa d b b cd d d e ab f url thumbnail https api asm skype com v objects sa d b b cd d d e ab f views imgt anim type picture doc id sa d b b cd d d e ab f width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d b b cd d d e ab f https login skype com login sso go xmmfallback pic sa d b b cd d d e ab f a originalname v screenshot from png originalname filesize v filesize meta type photo originalname screenshot from png meta uriobject',
#   'partlist type missed alt oid a a de d db c part identity live bcf e b d name anil taninki name part part identity live cid a bf name support ineuron ai name part partlist',
#   'how to solve this issue i tried every thing but no result',
#   'ss type hi wave ss',
#   'hello sir i am from mldl th june batch and dlcvnpl th july batch i have applied for internship but after attending yesterday s session i dont think i am ready for the internship so if my name is enrolled for internship kindly post it to next internship',
#   'sure',
#   'can you sujjest me some sites name other than flipkart',
#   'actually i implemented it separately',
#   'partlist type missed alt callid ccde d aa f d eee dff part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'sir in this line what basically and p doing',
#   'am getting',
#   'partlist type ended alt callid b b ce ff db b a e bbd e part identity live yash december name yash agrawal name duration duration part part identity live cid a bf name support ineuron ai name duration duration part partlist',
#   'hi',
#   'uriobject uri https api asm skype com v objects sa d ae b a e adb f be e url thumbnail https api asm skype com v objects sa d ae b a e adb f be e views imgt anim type picture doc id sa d ae b a e adb f be e width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ae b a e adb f be e https login skype com login sso go xmmfallback pic sa d ae b a e adb f be e a originalname v jpeg originalname filesize v filesize meta type photo originalname jpeg meta uriobject',
#   'thank you sir',
#   'okay i will try',
#   'the name is same for both the files i think',
#   'i apos m just asking for learning purposes',
#   'i already had python skills just want to bursh up my machine learning skills like eda nd machine learning models',
#   'okay',
#   'uriobject uri https api asm skype com v objects sa d ff fe c e ebfa e d e a url thumbnail https api asm skype com v objects sa d ff fe c e ebfa e d e a views imgt anim type picture doc id sa d ff fe c e ebfa e d e a width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d ff fe c e ebfa e d e a https login skype com login sso go xmmfallback pic sa d ff fe c e ebfa e d e a a originalname v untitled png originalname filesize v filesize meta type photo originalname untitled png meta uriobject',
#   'i have a doubt regarding this mail',
#   'here submit assignment button is not available',
#   'thanks',
#   'not recognised anything',
#   'can i send the problem statement and my code here',
#   'ok got it',
#   'this is just a coding doubt rather than a dataset wise doubt',
#   'cheers',
#   'i am telling pdf only',
#   'hii',
#   'yes but i think when u said that string is immutable it can be mutable through converting it into list and then back to tuples',
#   'sir i have changed that and that worked but still my main py is red',
#   'uriobject type picture uri https api asm skype com v objects sa d d a f url thumbnail https api asm skype com v objects sa d d a f views imgt to view this shared photo go to a href https login skype com login sso go xmmfallback amp pic sa d d a f https login skype com login sso go xmmfallback amp pic sa d d a f a originalname v img jpg filesize v meta type photo originalname img jpg uriobject',
#   'hi',
#   'no thank you i got it',
#   'could you please help me with this',
#   'sir instead of python i can use only python',
#   'uriobject uri https api asm skype com v objects sa d e b ede abba edb e ca b url thumbnail https api asm skype com v objects sa d e b ede abba edb e ca b views imgt anim type picture doc id sa d e b ede abba edb e ca b width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d e b ede abba edb e ca b https login skype com login sso go xmmfallback pic sa d e b ede abba edb e ca b a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'yes but i think when u said that string is immutable it can be mutable through converting it into list and then back to tuples',
#   'sir my python version is and need scikit learn for my project which is incompatible with python so what should i do',
#   'how to convert this in jupiter notebook',
#   'hello sir',
#   'sir when i m trying to run main py it is showing method object is not subscriptable what does this means can u tell me sir',
#   'hi',
#   'sure',
#   'ok sir',
#   'hello support team',
#   'uriobject uri https api asm skype com v objects sa d dd f e a fb c f d url thumbnail https api asm skype com v objects sa d dd f e a fb c f d views imgt anim type picture doc id sa d dd f e a fb c f d width height to view this shared photo go to a href https login skype com login sso go xmmfallback pic sa d dd f e a fb c f d https login skype com login sso go xmmfallback pic sa d dd f e a fb c f d a originalname v image t z png originalname filesize v filesize meta type photo originalname image t z png meta uriobject',
#   'thank you sir',
#   'hi sir',
#   ...]]

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 14.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 50.5MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.10.2 transformers-4.5.1

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
model_name = 'google/pegasus-xsum'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1912529.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=65.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=87.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=3520083.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1362.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=2275329241.0, style=ProgressStyle(descr…

# %%
text = " ".join(store)

# %%
Preprocessed_text = "summarize: "+text

# %%
s='yes but i think when u said that string is immutable it can be mutable through converting it into list and then back to tuples',

# %%
st = 'sir when i m trying to run main py it is showing method object is not subscriptable what does this means can u tell me sir'

# %%
batch = tokenizer.prepare_seq2seq_batch(src_texts=st ,truncation=True, padding='max_length', return_tensors="pt")
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3226: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,

# %%
tgt_text
# Out:
# ['sir when i m trying to run main py it is showing method object is not subscriptable what is it?']

# %%
Path = "pegasus.pt"

# %%
torch.save(model.state_dict(), Path)
